# %% [markdown]
# # Command line and data frames
#
#
# Spring 2017 - Prof. Foster Provost
#
# Teacher Assistant: Maria L Zamora Maass
#
#
# ***

# %% [markdown]
# ## Command Line (Terminal)

# %% [markdown]
# One of the most underappreciated tools for dealing with data is the command line of the Unix operating system. As you probably know, an operating system runs computer-based devices, including servers, laptops, smartphones, and many others, usually "under the hood".   "Unix" is the family of operating systems that runs the most devices.  If you have a Mac -- there's Unix under the hood.  An iPhone?  Unix under the hood. An Android phone? Guess what ... Unix under the hood.  And your cloud instance?  You guessed it.
#
# You can get under the hood of a Unix-based computer via the command line, often called the Terminal, and do all manner of crazy things.  We will study a few of them.
#
# We can access the command line of our instances through the Ipython Notebooks. You can use "shell" commands (such as the following) by prefixing the line with an exclamation point.
#
# (The "shell" is a technical name for the command line interface you see in a Terminal window.  There are actually different shells with different commands & syntax, even for the same operating system, but we won't delve into that in this class.  We will use the particular shell that AWS provides us by default.  The default is the "bash" shell, for those of you who care.)
#
# *Here we will give you a brief overview, and show some very useful commands.  If you're serious about dealing with data, and you don't have much command-line experience, you should get the book "Data Science at the Command Line" by Janssens. The first half of this (thin) book gives an excellent practical guide to dealing with data at the Unix command line.*

# %% [markdown]
# #### Interaction with files and folders
#
# We can navigate the folder structure in which we are working.  Folders are called "directories". You will typically use commands such as `ls` (list directory contents) and `cd` (change to another directory). You can make a directory with `mkdir` or move (`mv`) and copy (`cp`) files. To delete a file you can `rm` (remove) it--careful, there's no getting it back.  To see the contents of a file you can `cat` it to the screen.  (Why `cat`?  That command actually concatenates multiple files and outputs the result.  If you give it one, then it just outputs that single file.  The default is to output it to the screen.  You'll see below that we can send command outputs elsewhere besides to the screen--like into another command!)
#
# Many commands have options you can set when running them. For example to get a listing of files as a vertical list with extra details you can pass the `-l` (list) flag, e.g. `ls -l`. During the normal course of using the command line, you will learn the most useful flags. If you want to see all possible options you can always read the `man` (manual) page for a command, e.g. `man ls`. When you are done reading the `man` page, you can exit by hitting `q` to quit.

# %%
# !ls
# Out:
# Command_line_and_data_frames_2017.ipynb images
# data

# %%
# !ls -l
# Out:
# total 1056
# -rw-r--r--   1 mariazamora  staff  536994 Feb 21 17:33 Command_line_and_data_frames_2017.ipynb
# drwxr-xr-x   5 mariazamora  staff     170 Feb 13 23:53 data
# drwxr-xr-x  12 mariazamora  staff     408 Feb  6 17:44 images

# %%
# !mkdir test

# %%
# !ls
# Out:
# Command_line_and_data_frames_2017.ipynb images
# data                                    test

# %%
# !ls images/
# Out:
# new_notebook.png   notebook.png       terminal.png
# new_terminal.png   script.png         terminal_2017.png
# new_text.png       selectlanguage.png text.png

# %%
# !cp images/terminal.png test/some_picture.png

# %%
# !ls test/
# Out:
# some_picture.png

# %%
# WARNING: THIS WILL DELETE THE TEST FOLDER JUST CREATED
# !rm -rf test/

# %%
# !ls
# Out:
# Command_line_and_data_frames_2017.ipynb images
# data

# %% [markdown]
# #### Data manipulation and exploration
# Virtually anything you want to do with a data file can be done at the command line. There are dozens of commands that can be put together to get almost any result! Let's try it.
#
# Lets take a look at the the file `data/users.csv`.
#
# Before we do anything, lets take a look at the first few lines of the file to get an idea of what's in it.

# %%
# !head data/users.csv
# Out:
# user,variable1,variable2
# parallelconcerned,145.391881,-6.081689
# driftmvc,145.7887,-5.207083
# snowdonevasive,144.295861,-5.826789
# cobolglaucous,146.726242,-6.569828
# stylishmugs,147.22005,-9.443383
# hypergalaxyfibula,143.669186,-3.583828
# pipetsrockers,-45.425978,61.160517
# bracesworkable,-51.678064,64.190922
# spiritedjump,-50.689325,67.016969

# %% [markdown]
# Maybe we want to see a few more lines of the file,

# %%
# !head -15 data/users.csv
# Out:
# user,variable1,variable2
# parallelconcerned,145.391881,-6.081689
# driftmvc,145.7887,-5.207083
# snowdonevasive,144.295861,-5.826789
# cobolglaucous,146.726242,-6.569828
# stylishmugs,147.22005,-9.443383
# hypergalaxyfibula,143.669186,-3.583828
# pipetsrockers,-45.425978,61.160517
# bracesworkable,-51.678064,64.190922
# spiritedjump,-50.689325,67.016969
# barnevidence,-68.703161,76.531203
# emeraldclippers,-18.072703,65.659994
# maintainwiggly,-14.401389,65.283333
# submittedwavelength,-15.227222,64.295556
# clucklinnet,-17.425978,65.952328

# %% [markdown]
# How about the last few lines of the file?

# %%
# !tail data/users.csv
# Out:
# troubledseptum,135.521667,-29.716667
# troubledseptum,-118.598889,34.256944
# organicmajor,-5.435,36.136
# cobolglaucous,-123.5,48.85
# troubledseptum,-124.016667,49.616667
# snaildossier,-124.983333,50.066667
# unbalancedprotoplanet,-127.028611,50.575556
# badgefields,-126.833333,50.883333
# backedammeter,-123.00596,48.618397
# clucklinnet,-117.1995,32.7552

# %% [markdown]
# We can count how many lines are in the file by using `wc` (wordcount--which counts more than just words) with the `-l` flag to count lines,

# %%
# !wc -l data/users.csv
# Out:
#     8104 data/users.csv

# %% [markdown]
# It looks like there are three columns in this file, lets take a look at the first one alone. Here, we can `cut` the field (`-f`) we want as long as we give the proper delimeter to tell what separates fields (`-d` defaults to tab).

# %%
# !cut -f1 -d',' data/users.csv
# Out:
# user
# parallelconcerned
# driftmvc
# snowdonevasive
# cobolglaucous
# stylishmugs
# hypergalaxyfibula
# pipetsrockers
# bracesworkable
# spiritedjump
# barnevidence
# emeraldclippers
# maintainwiggly
# submittedwavelength
# clucklinnet
# bluetailgodwottery
# microwavejar
# croutonwrack
# submittedwavelength
# moderatohorn
# heaterinert
# micaassistant
# gaudyfea
# turnoverlovesick
# amuckpoints
# allegatorwafers
# expecteffective
# mincegaiters
# peacefulceaseless
# decanterbalance
# synonympatisserie
# starbucksbluetail
# pipeathlete
# radicandoceanic
# somethingalbedo
# craytugofwar
# pipetsrockers
# unbalancedprotoplanet
# emeraldclippers
# ischemicfrosted
# binomialapathetic
# stairsgobsmacked
# ledgeindeed
# badgefields
# synonympatisserie
# worldlyventuri
# globeshameful
# alloweruptions
# burritoscarriage
# grabbig
# dronessomersault
# latticelaboratory
# ellipticalfabricator
# amuckpoints
# guavaconfide
# fundingticket
# croutonwrack
# elatedunicorn
# freelysociable
# loindecorate
# micaassistant
# dweebspices
# latticelaboratory
# babyambitious
# specifiedinnovative
# colonclipper
# pipeathlete
# cranesurgeon
# belchedsodding
# actuallyfoot
# horsesmultiply
# microwavejar
# snaildossier
# globeshameful
# eontop
# tendonwench
# flakyunlawful
# twitequiver
# showerspain
# figsql
# barnevidence
# shrillbanjos
# maintainwiggly
# fundingticket
# planktonuses
# elatedunicorn
# agenascientists
# barnevidence
# swankythough
# paddlevacuole
# stairsgobsmacked
# flickcanapes
# unicyclistamiable
# hypergalaxyfibula
# mtvgrosbeak
# wordsundress
# ledgeindeed
# moderatohorn
# alloweruptions
# surmiseteenagers
# somethingalbedo
# somethingalbedo
# hoursethanoate
# looroasting
# lymphomamellow
# stylishmugs
# dampedbrioche
# craytugofwar
# unguardedgiant
# wordsundress
# unbalancedprotoplanet
# epsiloncloning
# ytterbiumprovincial
# disjointtoday
# gogglesknacker
# croutonwrack
# bashrower
# bunchmeats
# binomialapathetic
# behaveterminal
# wonderfulscullian
# sortinterior
# loindecorate
# paddlevacuole
# hoovessquares
# hoovessquares
# musicalchampagne
# eontop
# guavaconfide
# chiselleddessicants
# popmatrices
# poundingfrustum
# easybobolink
# wisefumbling
# compareas
# clucklinnet
# meggingswine
# sectionssqueaky
# crepegrape
# crepegrape
# neckedjre
# micaassistant
# twitequiver
# bluetailgodwottery
# xslhopeful
# farrowcetti
# craytugofwar
# peacefulceaseless
# cranniescigarette
# singesculptor
# specifiedinnovative
# emeraldclippers
# tendonwench
# dampedbrioche
# snowdonevasive
# colonclipper
# bracesworkable
# duexslt
# simplicityfairy
# hoursethanoate
# flakyunlawful
# tendonwench
# showerspain
# showerspain
# lasttaiga
# canalhateful
# rappelarias
# hypergalaxyfibula
# historypant
# rubbishbladder
# elatedunicorn
# cranniescigarette
# cranesurgeon
# disjointtoday
# agenascientists
# handywrist
# ledgeindeed
# gammagot
# blythpulse
# blythpulse
# impetuousfurbelows
# guavaconfide
# gravelscientific
# strungebay
# analbar
# xslhopeful
# wisefumbling
# compareas
# gnarledbaggy
# mincegaiters
# sociablelemma
# gnarledbaggy
# gogglesknacker
# snowdonevasive
# cleaningburnt
# hoovessquares
# binomialapathetic
# flinkjordan
# tyrespan
# moderatohorn
# allegatorwafers
# europiumcentury
# bluetailgodwottery
# quadratcranky
# simplicityfairy
# wordsundress
# feverspolystyrene
# batchquickest
# alloweruptions
# alloweruptions
# mtvgrosbeak
# snowdonevasive
# compareas
# fattyoddball
# sectionssqueaky
# fattyoddball
# fattyoddball
# guavaconfide
# maintainwiggly
# tyrespan
# behaviourverbena
# meggingswine
# elatedunicorn
# ytterbiumprovincial
# clucklinnet
# tweezerscurve
# gaudyfea
# freelysociable
# canalhateful
# tubingwheatear
# surmiseteenagers
# fattyoddball
# deficientclunking
# spiritedjump
# fattyoddball
# belchedsodding
# gammagot
# neighborlyrook
# completionskylark
# babyambitious
# deficientclunking
# trapdoormongrel
# singesculptor
# rigelpaunchy
# canalhateful
# completionskylark
# dweebspices
# trapdoormongrel
# microwavejar
# mincegaiters
# trapdoormongrel
# gogglesknacker
# backedammeter
# epsiloncloning
# copalinstruct
# amuckpoints
# trapdoormongrel
# risottospell
# dialgraft
# axlevirtue
# cleaningburnt
# listenerabandoned
# pipeathlete
# gogglesknacker
# hoovessquares
# replacedbevy
# snowdonevasive
# ashamedmuscles
# musicalchampagne
# cowardlyabout
# hoovessquares
# stairsgobsmacked
# eminentallergy
# eontop
# twitequiver
# binomialapathetic
# horsesmultiply
# simplicityfairy
# peacefulceaseless
# singesculptor
# bunchmeats
# meggingswine
# heomicron
# farrowcetti
# fizzlehelp
# bonelliseal
# ashamedmuscles
# deficientclunking
# neighborlyrook
# turnoverlovesick
# popmatrices
# stairsgobsmacked
# ellipticalfabricator
# gnarledbaggy
# sectionssqueaky
# gilletteclammy
# analbar
# raggedshrink
# grabbig
# unbalancedprotoplanet
# singesculptor
# bismuthcolloquial
# worldlyventuri
# guavaconfide
# chiselleddessicants
# trapdoormongrel
# ceilinjuries
# rappelarias
# gnarledbaggy
# sectionssqueaky
# europiumcentury
# gammagot
# dotwazzack
# radicandoceanic
# fixnumquicklime
# opticsdiameter
# nursingrash
# fixnumquicklime
# synonympatisserie
# applyingbaker
# chiselleddessicants
# freelysociable
# ashamedmuscles
# bashrower
# handywrist
# emeraldclippers
# europiumcentury
# fizzclimbing
# rappelarias
# hoovessquares
# tyrespan
# swankythough
# axlevirtue
# looroasting
# upbeatodd
# gilletteclammy
# ellipticalfabricator
# lasttaiga
# musicalchampagne
# buoyancycowardice
# fixnumquicklime
# hoovessquares
# handywrist
# rappelarias
# producecoven
# colonclipper
# cheapersyllable
# unbalancedprotoplanet
# unicyclistamiable
# clucklinnet
# simplicityfairy
# applyingbaker
# synonympatisserie
# casesslippery
# pancakesgrebe
# driftmvc
# blythpulse
# unguardedgiant
# bashrower
# opticsdiameter
# unbalancedprotoplanet
# bismuthcolloquial
# unicyclistamiable
# ischemicfrosted
# feverspolystyrene
# copalinstruct
# ellipticalfabricator
# axlevirtue
# swankythough
# sectionssqueaky
# moderatohorn
# synonympatisserie
# bracesworkable
# cranesurgeon
# stylishmugs
# translatecyclist
# gruntdrive
# wisefumbling
# troubledseptum
# bismuthcolloquial
# hoovessquares
# flakyunlawful
# apronextension
# neighborlyrook
# advisorlanguage
# dotwazzack
# organicmajor
# craytugofwar
# chichazard
# gammagot
# badgefields
# sociablelemma
# disjointtoday
# quadratcranky
# singesculptor
# xslhopeful
# eontop
# cobolglaucous
# guavaconfide
# ischemicfrosted
# guavaconfide
# buoyancycowardice
# shrillbanjos
# ledgeindeed
# advisorlanguage
# handywrist
# allocatesposts
# barnevidence
# actuallyfoot
# ischemicfrosted
# tubingwheatear
# europiumcentury
# somethingalbedo
# easybobolink
# turnoverlovesick
# advisorlanguage
# stylishmugs
# flickcanapes
# stunassured
# freelysociable
# surmiseteenagers
# pancakesgrebe
# rigelpaunchy
# sociablelemma
# ytterbiumprovincial
# sortinterior
# producecoven
# deficientclunking
# looroasting
# simplicityfairy
# worldlyventuri
# figsql
# poundingfrustum
# freelysociable
# agenascientists
# organicmajor
# hoovessquares
# smackswallow
# musicalchampagne
# paddlevacuole
# troubledseptum
# meatsoffbeat
# upbeatodd
# realtorcaustic
# cartridgesbummage
# wisefumbling
# meggingswine
# sectionssqueaky
# ceilinjuries
# latticelaboratory
# grabbig
# figsql
# upbeatodd
# buoyancycowardice
# hoursethanoate
# neckedjre
# mtvgrosbeak
# parallelconcerned
# latticelaboratory
# eontop
# poundingfrustum
# dampedbrioche
# looroasting
# rappelarias
# badgefields
# clucklinnet
# frequencywould
# listenerabandoned
# carrionscream
# rubbishbladder
# unguardedgiant
# worldlyventuri
# meatsoffbeat
# smackswallow
# poundingfrustum
# canalhateful
# craytugofwar
# binomialapathetic
# eontop
# lasttaiga
# metaiota
# apronextension
# bonelliseal
# risottospell
# dialgraft
# strungebay
# upbeatodd
# metaiota
# wordsundress
# moderatohorn
# rappelarias
# historypant
# historypant
# organicmajor
# alloweruptions
# applyingbaker
# frequencywould
# raggedshrink
# somethingalbedo
# applyingbaker
# chiselleddessicants
# behaviourverbena
# decanterbalance
# heaterinert
# troubledseptum
# burntrifle
# blythpulse
# heaterinert
# dotwazzack
# lymphomamellow
# crepegrape
# replacedbevy
# realtorcaustic
# sectionssqueaky
# langeredsubset
# feverspolystyrene
# europiumcentury
# backedammeter
# axlevirtue
# quadratcranky
# expecteffective
# mtvgrosbeak
# latticelaboratory
# advisorlanguage
# poohvireo
# wonderfulscullian
# craytugofwar
# flakyunlawful
# emeraldclippers
# tubingwheatear
# compareas
# risottospell
# troubledseptum
# translatecyclist
# moderatohorn
# handywrist
# sociablelemma
# loindecorate
# producecoven
# organicmajor
# eontop
# batchquickest
# eontop
# batchquickest
# tweezerscurve
# globeshameful
# moderatohorn
# cranniescigarette
# meatsoffbeat
# ceilinjuries
# trapdoormongrel
# ledgeindeed
# microwavejar
# singesculptor
# looroasting
# metaiota
# fizzlehelp
# replacedbevy
# gnarledbaggy
# allegatorwafers
# dweebspices
# hoovessquares
# flickcanapes
# simplicityfairy
# allocatesposts
# chichazard
# binomialapathetic
# stylishmugs
# dampedbrioche
# troubledseptum
# rubbishbladder
# flinkjordan
# mincegaiters
# impetuousfurbelows
# historypant
# dialgraft
# opticsdiameter
# pipeathlete
# globeshameful
# cartridgesbummage
# smackswallow
# bashrower
# upbeatodd
# fizzlehelp
# sociablelemma
# cobolglaucous
# meatsoffbeat
# tyrespan
# expecteffective
# lasttaiga
# handywrist
# raggedshrink
# fizzlehelp
# compareas
# meatsoffbeat
# upbeatodd
# replacedbevy
# gravelscientific
# chichazard
# barnevidence
# neckedjre
# privacyhaunt
# popmatrices
# troubledseptum
# mtvgrosbeak
# crepegrape
# decanterbalance
# risottospell
# eontop
# strungebay
# unbalancedprotoplanet
# raggedshrink
# burritoscarriage
# showerspain
# dampedbrioche
# bracesworkable
# ashamedmuscles
# parallelconcerned
# heomicron
# gaudyfea
# producecoven
# replacedbevy
# allegatorwafers
# planktonuses
# swankythough
# horsesmultiply
# phobosstaccato
# gilletteclammy
# dampedbrioche
# pipeathlete
# babyambitious
# ceilinjuries
# mincegaiters
# binomialapathetic
# sociablelemma
# upbeatodd
# colonclipper
# unbalancedprotoplanet
# amuckpoints
# moderatohorn
# planktonuses
# mtvgrosbeak
# musicalchampagne
# impetuousfurbelows
# cuboidpass
# gilletteclammy
# burntrifle
# gruntdrive
# badgefields
# realtorcaustic
# realtorcaustic
# dotwazzack
# bunchmeats
# smackswallow
# advisorlanguage
# flinkjordan
# fixnumquicklime
# coatprecious
# colonclipper
# fizzlehelp
# chichazard
# allocatesposts
# earmarinated
# guavaconfide
# badgefields
# barnevidence
# compareas
# fixnumquicklime
# simplicityfairy
# phobosstaccato
# feverspolystyrene
# europiumcentury
# risottospell
# babyambitious
# duexslt
# lasttaiga
# alloweruptions
# popmatrices
# tendonwench
# hypergalaxyfibula
# ledgeindeed
# burntrifle
# peacefulceaseless
# binomialapathetic
# geologybeeping
# organicmajor
# peacefulceaseless
# deficientclunking
# paddlevacuole
# handywrist
# xslhopeful
# fizzlehelp
# eminentallergy
# bunchmeats
# ashamedmuscles
# simplicityfairy
# singesculptor
# earmarinated
# meatsoffbeat
# pipetsrockers
# applyingbaker
# gnarledbaggy
# heaterinert
# emeraldclippers
# gaudyfea
# farrowcetti
# gammagot
# allocatesposts
# rubbishbladder
# gogglesknacker
# axlevirtue
# flinkjordan
# bismuthcolloquial
# wisefumbling
# ceilinjuries
# worldlyventuri
# ashamedmuscles
# cranesurgeon
# bluetailgodwottery
# unbalancedprotoplanet
# pipeathlete
# mincegaiters
# rigelpaunchy
# synonympatisserie
# analbar
# tubingwheatear
# actuallyfoot
# meggingswine
# sociablelemma
# cobolglaucous
# ashamedmuscles
# dweebspices
# poundingfrustum
# batchquickest
# peacefulceaseless
# dronessomersault
# swankythough
# tendonwench
# dialgraft
# fattyoddball
# batchquickest
# coatprecious
# apronextension
# mincegaiters
# radicandoceanic
# flickcanapes
# burntrifle
# disjointtoday
# troubledseptum
# tyrespan
# tendonwench
# hypergalaxyfibula
# metaiota
# smackswallow
# stairsgobsmacked
# twitequiver
# neighborlyrook
# burntrifle
# feverspolystyrene
# micaassistant
# cobolglaucous
# ledgeindeed
# impetuousfurbelows
# belchedsodding
# radicandoceanic
# bunchmeats
# replacedbevy
# freelysociable
# bunchmeats
# surmiseteenagers
# latticelaboratory
# gammagot
# poohvireo
# popmatrices
# rappelarias
# turnoverlovesick
# langeredsubset
# wonderfulscullian
# snaildossier
# craytugofwar
# ashamedmuscles
# eminentallergy
# fattyoddball
# translatecyclist
# lasttaiga
# europiumcentury
# handywrist
# mtvgrosbeak
# easybobolink
# gogglesknacker
# realtorcaustic
# neckedjre
# lickerbond
# bluetailgodwottery
# lickerbond
# barnevidence
# wordsundress
# blythpulse
# musicalchampagne
# xslhopeful
# smackswallow
# expecteffective
# driftmvc
# submittedwavelength
# dialgraft
# alloweruptions
# loindecorate
# farrowcetti
# burritoscarriage
# completionskylark
# mtvgrosbeak
# copalinstruct
# fattyoddball
# peacefulceaseless
# copalinstruct
# pleasinghoop
# disjointtoday
# compareas
# frequencywould
# gilletteclammy
# historypant
# tubingwheatear
# smackswallow
# upbeatodd
# gogglesknacker
# singesculptor
# popmatrices
# rigelpaunchy
# wordsundress
# croutonwrack
# trapdoormongrel
# smackswallow
# ceilinjuries
# translatecyclist
# globeshameful
# sortinterior
# binomialapathetic
# upbeatodd
# dweebspices
# replacedbevy
# latticelaboratory
# easybobolink
# tyrespan
# lickerbond
# radicandoceanic
# snaildossier
# cuboidpass
# gravelscientific
# spiritedjump
# micaassistant
# stunassured
# spiritedjump
# completionskylark
# dialgraft
# eminentallergy
# lickerbond
# barnevidence
# snowdonevasive
# parallelconcerned
# copalinstruct
# specifiedinnovative
# peacefulceaseless
# ashamedmuscles
# burritoscarriage
# dotwazzack
# driftmvc
# loindecorate
# specifiedinnovative
# poundingfrustum
# pipeathlete
# privacyhaunt
# guavaconfide
# axlevirtue
# namibianstabbing
# amuckpoints
# wonderfulscullian
# cobolglaucous
# quadratcranky
# poohvireo
# gruntdrive
# burntrifle
# listenerabandoned
# cartridgesbummage
# bunchmeats
# burntrifle
# crepegrape
# phobosstaccato
# instantthwack
# evaporatingplug
# singesculptor
# dampedbrioche
# specifiedinnovative
# feverspolystyrene
# upbeatodd
# cartridgesbummage
# farrowcetti
# binomialapathetic
# unguardedgiant
# stunassured
# cheapersyllable
# risottospell
# privacyhaunt
# moderatohorn
# decanterbalance
# gilletteclammy
# alloweruptions
# analbar
# neckedjre
# chiselleddessicants
# turnoverlovesick
# fundingticket
# planktonuses
# risottospell
# micaassistant
# tweezerscurve
# raggedshrink
# flinkjordan
# frequencywould
# cleaningburnt
# eontop
# cheapersyllable
# fixnumquicklime
# gnarledbaggy
# guavaconfide
# sociablelemma
# dweebspices
# hypergalaxyfibula
# handywrist
# twitequiver
# realtorcaustic
# bonelliseal
# epsiloncloning
# axlevirtue
# trapdoormongrel
# disjointtoday
# unguardedgiant
# pipetsrockers
# amuckpoints
# pancakesgrebe
# compareas
# ledgeindeed
# poundingfrustum
# fattyoddball
# sociablelemma
# burntrifle
# europiumcentury
# snaildossier
# gruntdrive
# sociablelemma
# troubledseptum
# babyambitious
# worldlyventuri
# disjointtoday
# bunchmeats
# bashrower
# tubingwheatear
# evaporatingplug
# strungebay
# rubbishbladder
# nursingrash
# unicyclistamiable
# buoyancycowardice
# actuallyfoot
# expecteffective
# neckedjre
# croutonwrack
# barnevidence
# bracesworkable
# elatedunicorn
# lymphomamellow
# ceilinjuries
# behaveterminal
# allegatorwafers
# wonderfulscullian
# namibianstabbing
# flinkjordan
# chichazard
# peacefulceaseless
# burntrifle
# loindecorate
# driftmvc
# mtvgrosbeak
# specifiedinnovative
# colonclipper
# hoovessquares
# freelysociable
# hoovessquares
# fizzlehelp
# hoursethanoate
# historypant
# unbalancedprotoplanet
# crepegrape
# dronessomersault
# xslhopeful
# agenascientists
# planktonuses
# cobolglaucous
# surmiseteenagers
# driftmvc
# amuckpoints
# grabbig
# cowardlyabout
# sortinterior
# smackswallow
# troubledseptum
# bashrower
# synonympatisserie
# rubbishbladder
# batchquickest
# completionskylark
# fattyoddball
# mincegaiters
# bismuthcolloquial
# freelysociable
# fizzlehelp
# snaildossier
# stunassured
# alloweruptions
# fizzlehelp
# lickerbond
# bunchmeats
# chiselleddessicants
# translatecyclist
# feverspolystyrene
# deficientclunking
# alloweruptions
# apronextension
# smackswallow
# ashamedmuscles
# parallelconcerned
# nursingrash
# pancakesgrebe
# frequencywould
# cuboidpass
# strungebay
# fattyoddball
# starbucksbluetail
# starbucksbluetail
# bracesworkable
# worldlyventuri
# pancakesgrebe
# heomicron
# latticelaboratory
# meggingswine
# latticelaboratory
# duexslt
# fizzclimbing
# feverspolystyrene
# behaviourverbena
# coatprecious
# instantthwack
# cobolglaucous
# dronessomersault
# decanterbalance
# organicmajor
# rappelarias
# pipetsrockers
# raggedshrink
# dweebspices
# fixnumquicklime
# ashamedmuscles
# surmiseteenagers
# europiumcentury
# clucklinnet
# actuallyfoot
# flinkjordan
# amuckpoints
# replacedbevy
# burntrifle
# poundingfrustum
# blythpulse
# crepegrape
# behaviourverbena
# unicyclistamiable
# tendonwench
# cartridgesbummage
# fizzlehelp
# poundingfrustum
# worldlyventuri
# musicalchampagne
# sociablelemma
# souffleutility
# shrillbanjos
# singesculptor
# guavaconfide
# binomialapathetic
# somethingalbedo
# clucklinnet
# looroasting
# alloweruptions
# grabbig
# stairsgobsmacked
# barnevidence
# microwavejar
# geologybeeping
# langeredsubset
# loindecorate
# heomicron
# sortinterior
# quadratcranky
# trapdoormongrel
# opticsdiameter
# casesslippery
# poundingfrustum
# tubingwheatear
# babyambitious
# replacedbevy
# burntrifle
# heaterinert
# stairsgobsmacked
# badgefields
# allocatesposts
# turnoverlovesick
# meatsoffbeat
# compareas
# dronessomersault
# cranniescigarette
# croutonwrack
# shrillbanjos
# snowdonevasive
# apronextension
# sectionssqueaky
# epsiloncloning
# rigelpaunchy
# actuallyfoot
# snowdonevasive
# burntrifle
# heaterinert
# babyambitious
# fizzclimbing
# latticelaboratory
# eminentallergy
# croutonwrack
# radicandoceanic
# troubledseptum
# popmatrices
# wisefumbling
# babyambitious
# wordsundress
# axlevirtue
# loindecorate
# langeredsubset
# emeraldclippers
# guavaconfide
# actuallyfoot
# heomicron
# ellipticalfabricator
# looroasting
# simplicityfairy
# xslhopeful
# bracesworkable
# globeshameful
# langeredsubset
# flakyunlawful
# quadratcranky
# europiumcentury
# raggedshrink
# gnarledbaggy
# metaiota
# hypergalaxyfibula
# croutonwrack
# badgefields
# flickcanapes
# eontop
# ischemicfrosted
# rigelpaunchy
# badgefields
# strungebay
# radicandoceanic
# binomialapathetic
# gammagot
# privacyhaunt
# grabbig
# dampedbrioche
# dampedbrioche
# pipetsrockers
# metaiota
# mtvgrosbeak
# simplicityfairy
# bismuthcolloquial
# dronessomersault
# analbar
# compareas
# pancakesgrebe
# radicandoceanic
# figsql
# nursingrash
# applyingbaker
# troubledseptum
# applyingbaker
# tendonwench
# mincegaiters
# duexslt
# unguardedgiant
# casesslippery
# lymphomamellow
# risottospell
# binomialapathetic
# binomialapathetic
# freelysociable
# looroasting
# coatprecious
# copalinstruct
# compareas
# earmarinated
# bunchmeats
# casesslippery
# evaporatingplug
# frequencywould
# compareas
# loindecorate
# popmatrices
# buoyancycowardice
# quadratcranky
# farrowcetti
# specifiedinnovative
# geologybeeping
# microwavejar
# geologybeeping
# gammagot
# rubbishbladder
# strungebay
# spiritedjump
# metaiota
# burntrifle
# twitequiver
# turnoverlovesick
# decanterbalance
# figsql
# bunchmeats
# specifiedinnovative
# compareas
# dotwazzack
# cleaningburnt
# dronessomersault
# evaporatingplug
# lickerbond
# worldlyventuri
# chiselleddessicants
# europiumcentury
# actuallyfoot
# tyrespan
# badgefields
# snaildossier
# chiselleddessicants
# handywrist
# alloweruptions
# ytterbiumprovincial
# impetuousfurbelows
# gilletteclammy
# fattyoddball
# ceilinjuries
# smackswallow
# dronessomersault
# strungebay
# neckedjre
# applyingbaker
# meatsoffbeat
# peacefulceaseless
# flakyunlawful
# rubbishbladder
# singesculptor
# unicyclistamiable
# freelysociable
# cuboidpass
# worldlyventuri
# surmiseteenagers
# unbalancedprotoplanet
# easybobolink
# gogglesknacker
# rubbishbladder
# radicandoceanic
# singesculptor
# unbalancedprotoplanet
# instantthwack
# flakyunlawful
# flakyunlawful
# stairsgobsmacked
# rigelpaunchy
# starbucksbluetail
# freelysociable
# binomialapathetic
# evaporatingplug
# hypergalaxyfibula
# smackswallow
# canalhateful
# copalinstruct
# farrowcetti
# europiumcentury
# peacefulceaseless
# analbar
# instantthwack
# micaassistant
# cranniescigarette
# applyingbaker
# nursingrash
# poohvireo
# starbucksbluetail
# alloweruptions
# hoursethanoate
# dronessomersault
# musicalchampagne
# cranniescigarette
# peacefulceaseless
# analbar
# decanterbalance
# sociablelemma
# meatsoffbeat
# moderatohorn
# microwavejar
# gogglesknacker
# tyrespan
# neckedjre
# sortinterior
# burritoscarriage
# organicmajor
# twitequiver
# wisefumbling
# dweebspices
# producecoven
# heomicron
# bluetailgodwottery
# opticsdiameter
# decanterbalance
# carrionscream
# gammagot
# rappelarias
# neighborlyrook
# quadratcranky
# listenerabandoned
# rigelpaunchy
# historypant
# gruntdrive
# latticelaboratory
# parallelconcerned
# figsql
# bonelliseal
# poundingfrustum
# wonderfulscullian
# completionskylark
# dotwazzack
# pipeathlete
# opticsdiameter
# showerspain
# applyingbaker
# trapdoormongrel
# lymphomamellow
# hoovessquares
# peacefulceaseless
# dweebspices
# driftmvc
# pipeathlete
# maintainwiggly
# worldlyventuri
# backedammeter
# organicmajor
# cartridgesbummage
# cleaningburnt
# rubbishbladder
# troubledseptum
# flinkjordan
# rigelpaunchy
# barnevidence
# hoursethanoate
# cranniescigarette
# mtvgrosbeak
# showerspain
# gilletteclammy
# tendonwench
# wonderfulscullian
# upbeatodd
# casesslippery
# bluetailgodwottery
# synonympatisserie
# freelysociable
# specifiedinnovative
# unicyclistamiable
# tweezerscurve
# upbeatodd
# babyambitious
# tweezerscurve
# applyingbaker
# crepegrape
# planktonuses
# gaudyfea
# europiumcentury
# earmarinated
# deficientclunking
# dialgraft
# specifiedinnovative
# frequencywould
# cleaningburnt
# crepegrape
# fixnumquicklime
# ashamedmuscles
# spiritedjump
# sectionssqueaky
# bunchmeats
# dialgraft
# realtorcaustic
# twitequiver
# globeshameful
# shrillbanjos
# unguardedgiant
# wordsundress
# pleasinghoop
# freelysociable
# showerspain
# disjointtoday
# epsiloncloning
# poundingfrustum
# gruntdrive
# casesslippery
# bashrower
# frequencywould
# specifiedinnovative
# bracesworkable
# impetuousfurbelows
# unbalancedprotoplanet
# lasttaiga
# lickerbond
# barnevidence
# peacefulceaseless
# wonderfulscullian
# chichazard
# burntrifle
# wisefumbling
# radicandoceanic
# gogglesknacker
# burritoscarriage
# fizzlehelp
# gruntdrive
# heaterinert
# gogglesknacker
# ellipticalfabricator
# listenerabandoned
# snowdonevasive
# cobolglaucous
# heaterinert
# parallelconcerned
# poundingfrustum
# ytterbiumprovincial
# burritoscarriage
# tyrespan
# apronextension
# disjointtoday
# trapdoormongrel
# showerspain
# craytugofwar
# shrillbanjos
# cheapersyllable
# compareas
# axlevirtue
# hoursethanoate
# submittedwavelength
# meatsoffbeat
# behaviourverbena
# barnevidence
# driftmvc
# sectionssqueaky
# parallelconcerned
# hypergalaxyfibula
# organicmajor
# looroasting
# expecteffective
# bismuthcolloquial
# ischemicfrosted
# actuallyfoot
# fizzclimbing
# emeraldclippers
# cheapersyllable
# behaveterminal
# barnevidence
# fattyoddball
# stunassured
# cuboidpass
# globeshameful
# risottospell
# epsiloncloning
# farrowcetti
# bonelliseal
# gogglesknacker
# planktonuses
# mtvgrosbeak
# shrillbanjos
# cranesurgeon
# cranniescigarette
# coatprecious
# lymphomamellow
# quadratcranky
# namibianstabbing
# synonympatisserie
# evaporatingplug
# fixnumquicklime
# burritoscarriage
# quadratcranky
# earmarinated
# flinkjordan
# colonclipper
# starbucksbluetail
# flinkjordan
# cowardlyabout
# craytugofwar
# bracesworkable
# bonelliseal
# gaudyfea
# rubbishbladder
# cartridgesbummage
# translatecyclist
# phobosstaccato
# impetuousfurbelows
# applyingbaker
# strungebay
# stunassured
# unicyclistamiable
# snowdonevasive
# apronextension
# troubledseptum
# cowardlyabout
# opticsdiameter
# pipetsrockers
# advisorlanguage
# copalinstruct
# wisefumbling
# compareas
# apronextension
# smackswallow
# fundingticket
# ischemicfrosted
# maintainwiggly
# bismuthcolloquial
# behaveterminal
# upbeatodd
# grabbig
# gravelscientific
# cowardlyabout
# sectionssqueaky
# gogglesknacker
# submittedwavelength
# gaudyfea
# submittedwavelength
# neckedjre
# handywrist
# tubingwheatear
# batchquickest
# hoursethanoate
# actuallyfoot
# expecteffective
# apronextension
# pipeathlete
# canalhateful
# burritoscarriage
# deficientclunking
# decanterbalance
# micaassistant
# sociablelemma
# backedammeter
# rappelarias
# instantthwack
# ceilinjuries
# flickcanapes
# synonympatisserie
# disjointtoday
# gravelscientific
# carrionscream
# handywrist
# pleasinghoop
# neighborlyrook
# translatecyclist
# fizzlehelp
# neckedjre
# strungebay
# sortinterior
# strungebay
# canalhateful
# upbeatodd
# meatsoffbeat
# wonderfulscullian
# heomicron
# bonelliseal
# hoursethanoate
# privacyhaunt
# troubledseptum
# bunchmeats
# langeredsubset
# strungebay
# peacefulceaseless
# trapdoormongrel
# starbucksbluetail
# binomialapathetic
# starbucksbluetail
# somethingalbedo
# showerspain
# pipetsrockers
# completionskylark
# gilletteclammy
# earmarinated
# ellipticalfabricator
# eminentallergy
# eminentallergy
# bunchmeats
# crepegrape
# guavaconfide
# fattyoddball
# ischemicfrosted
# lickerbond
# rubbishbladder
# worldlyventuri
# frequencywould
# canalhateful
# looroasting
# clucklinnet
# snaildossier
# cleaningburnt
# dampedbrioche
# sectionssqueaky
# wordsundress
# gilletteclammy
# risottospell
# heaterinert
# flickcanapes
# submittedwavelength
# babyambitious
# compareas
# parallelconcerned
# nursingrash
# surmiseteenagers
# pleasinghoop
# fizzlehelp
# risottospell
# ashamedmuscles
# axlevirtue
# paddlevacuole
# swankythough
# producecoven
# peacefulceaseless
# troubledseptum
# maintainwiggly
# producecoven
# popmatrices
# wonderfulscullian
# dialgraft
# rappelarias
# upbeatodd
# showerspain
# paddlevacuole
# poundingfrustum
# latticelaboratory
# hoovessquares
# heomicron
# lasttaiga
# pleasinghoop
# dotwazzack
# troubledseptum
# xslhopeful
# stylishmugs
# apronextension
# dronessomersault
# canalhateful
# nursingrash
# advisorlanguage
# neckedjre
# binomialapathetic
# mincegaiters
# translatecyclist
# canalhateful
# grabbig
# replacedbevy
# gaudyfea
# babyambitious
# mincegaiters
# specifiedinnovative
# meatsoffbeat
# bluetailgodwottery
# duexslt
# gogglesknacker
# hypergalaxyfibula
# producecoven
# dotwazzack
# historypant
# wisefumbling
# pleasinghoop
# listenerabandoned
# planktonuses
# dialgraft
# bashrower
# langeredsubset
# popmatrices
# metaiota
# dotwazzack
# wonderfulscullian
# synonympatisserie
# completionskylark
# flickcanapes
# apronextension
# blythpulse
# actuallyfoot
# frequencywould
# alloweruptions
# guavaconfide
# musicalchampagne
# rubbishbladder
# frequencywould
# neighborlyrook
# paddlevacuole
# globeshameful
# axlevirtue
# hoovessquares
# wonderfulscullian
# evaporatingplug
# fattyoddball
# canalhateful
# duexslt
# easybobolink
# gammagot
# neckedjre
# planktonuses
# expecteffective
# cobolglaucous
# micaassistant
# elatedunicorn
# bunchmeats
# specifiedinnovative
# micaassistant
# buoyancycowardice
# smackswallow
# tendonwench
# nursingrash
# poundingfrustum
# ashamedmuscles
# fixnumquicklime
# somethingalbedo
# bashrower
# apronextension
# flinkjordan
# wordsundress
# paddlevacuole
# figsql
# behaviourverbena
# axlevirtue
# axlevirtue
# worldlyventuri
# alloweruptions
# risottospell
# ischemicfrosted
# ellipticalfabricator
# dampedbrioche
# badgefields
# behaveterminal
# lasttaiga
# cowardlyabout
# quadratcranky
# expecteffective
# fixnumquicklime
# stunassured
# starbucksbluetail
# producecoven
# bunchmeats
# stairsgobsmacked
# cheapersyllable
# dweebspices
# musicalchampagne
# raggedshrink
# axlevirtue
# twitequiver
# canalhateful
# badgefields
# gaudyfea
# croutonwrack
# dronessomersault
# opticsdiameter
# ceilinjuries
# evaporatingplug
# disjointtoday
# ischemicfrosted
# craytugofwar
# pancakesgrebe
# handywrist
# microwavejar
# europiumcentury
# shrillbanjos
# completionskylark
# copalinstruct
# rubbishbladder
# cobolglaucous
# cuboidpass
# duexslt
# organicmajor
# hypergalaxyfibula
# hoursethanoate
# simplicityfairy
# privacyhaunt
# flickcanapes
# feverspolystyrene
# peacefulceaseless
# ellipticalfabricator
# globeshameful
# fundingticket
# gruntdrive
# meatsoffbeat
# meatsoffbeat
# wonderfulscullian
# sortinterior
# burntrifle
# hoursethanoate
# handywrist
# pancakesgrebe
# globeshameful
# flickcanapes
# guavaconfide
# dampedbrioche
# snaildossier
# eminentallergy
# rubbishbladder
# strungebay
# expecteffective
# chichazard
# belchedsodding
# gammagot
# stairsgobsmacked
# alloweruptions
# surmiseteenagers
# nursingrash
# looroasting
# metaiota
# belchedsodding
# nursingrash
# farrowcetti
# meggingswine
# shrillbanjos
# epsiloncloning
# snaildossier
# listenerabandoned
# lickerbond
# radicandoceanic
# bracesworkable
# behaviourverbena
# metaiota
# bonelliseal
# moderatohorn
# simplicityfairy
# raggedshrink
# copalinstruct
# poohvireo
# maintainwiggly
# compareas
# simplicityfairy
# ledgeindeed
# tyrespan
# worldlyventuri
# showerspain
# craytugofwar
# stunassured
# guavaconfide
# xslhopeful
# smackswallow
# mtvgrosbeak
# namibianstabbing
# burntrifle
# gogglesknacker
# freelysociable
# lickerbond
# ceilinjuries
# allegatorwafers
# raggedshrink
# popmatrices
# wordsundress
# smackswallow
# expecteffective
# unicyclistamiable
# frequencywould
# metaiota
# babyambitious
# wonderfulscullian
# amuckpoints
# tyrespan
# epsiloncloning
# strungebay
# driftmvc
# easybobolink
# metaiota
# advisorlanguage
# listenerabandoned
# historypant
# clucklinnet
# stunassured
# chichazard
# lasttaiga
# rappelarias
# planktonuses
# tendonwench
# earmarinated
# dampedbrioche
# moderatohorn
# namibianstabbing
# mtvgrosbeak
# parallelconcerned
# earmarinated
# namibianstabbing
# tendonwench
# fattyoddball
# smackswallow
# backedammeter
# shrillbanjos
# impetuousfurbelows
# dampedbrioche
# surmiseteenagers
# microwavejar
# frequencywould
# figsql
# surmiseteenagers
# pancakesgrebe
# mincegaiters
# pancakesgrebe
# epsiloncloning
# batchquickest
# metaiota
# coatprecious
# meatsoffbeat
# replacedbevy
# craytugofwar
# poohvireo
# crepegrape
# sortinterior
# unicyclistamiable
# heomicron
# tubingwheatear
# langeredsubset
# lasttaiga
# driftmvc
# moderatohorn
# backedammeter
# smackswallow
# submittedwavelength
# advisorlanguage
# handywrist
# neckedjre
# nursingrash
# unbalancedprotoplanet
# surmiseteenagers
# fattyoddball
# europiumcentury
# decanterbalance
# lickerbond
# raggedshrink
# horsesmultiply
# gilletteclammy
# turnoverlovesick
# latticelaboratory
# wisefumbling
# batchquickest
# xslhopeful
# namibianstabbing
# dronessomersault
# bluetailgodwottery
# applyingbaker
# loindecorate
# flinkjordan
# flinkjordan
# ceilinjuries
# clucklinnet
# gilletteclammy
# gogglesknacker
# belchedsodding
# sectionssqueaky
# flickcanapes
# strungebay
# namibianstabbing
# pancakesgrebe
# unguardedgiant
# turnoverlovesick
# bracesworkable
# unguardedgiant
# phobosstaccato
# flinkjordan
# wonderfulscullian
# singesculptor
# spiritedjump
# flickcanapes
# europiumcentury
# dronessomersault
# fixnumquicklime
# paddlevacuole
# showerspain
# wordsundress
# copalinstruct
# dweebspices
# strungebay
# ceilinjuries
# rappelarias
# completionskylark
# elatedunicorn
# organicmajor
# gruntdrive
# snowdonevasive
# worldlyventuri
# tubingwheatear
# actuallyfoot
# compareas
# actuallyfoot
# specifiedinnovative
# dweebspices
# peacefulceaseless
# gilletteclammy
# badgefields
# duexslt
# cranniescigarette
# epsiloncloning
# looroasting
# bunchmeats
# submittedwavelength
# horsesmultiply
# stairsgobsmacked
# feverspolystyrene
# pipetsrockers
# cowardlyabout
# historypant
# pipetsrockers
# colonclipper
# synonympatisserie
# casesslippery
# microwavejar
# instantthwack
# surmiseteenagers
# colonclipper
# fixnumquicklime
# stylishmugs
# allocatesposts
# copalinstruct
# troubledseptum
# flakyunlawful
# completionskylark
# unbalancedprotoplanet
# driftmvc
# fizzclimbing
# mtvgrosbeak
# emeraldclippers
# ellipticalfabricator
# upbeatodd
# cleaningburnt
# figsql
# allegatorwafers
# badgefields
# decanterbalance
# ytterbiumprovincial
# pancakesgrebe
# expecteffective
# sortinterior
# gilletteclammy
# replacedbevy
# deficientclunking
# loindecorate
# casesslippery
# canalhateful
# easybobolink
# loindecorate
# wisefumbling
# flinkjordan
# hoovessquares
# cheapersyllable
# frequencywould
# realtorcaustic
# belchedsodding
# compareas
# neighborlyrook
# dotwazzack
# singesculptor
# alloweruptions
# souffleutility
# singesculptor
# ischemicfrosted
# badgefields
# pancakesgrebe
# gruntdrive
# coatprecious
# maintainwiggly
# croutonwrack
# axlevirtue
# ytterbiumprovincial
# farrowcetti
# microwavejar
# hypergalaxyfibula
# backedammeter
# maintainwiggly
# expecteffective
# figsql
# producecoven
# feverspolystyrene
# meggingswine
# poundingfrustum
# dotwazzack
# cleaningburnt
# hoursethanoate
# wonderfulscullian
# looroasting
# unbalancedprotoplanet
# croutonwrack
# wonderfulscullian
# micaassistant
# opticsdiameter
# pipetsrockers
# canalhateful
# gruntdrive
# gravelscientific
# namibianstabbing
# planktonuses
# namibianstabbing
# figsql
# gravelscientific
# tubingwheatear
# burritoscarriage
# allegatorwafers
# showerspain
# dotwazzack
# twitequiver
# fattyoddball
# elatedunicorn
# globeshameful
# phobosstaccato
# poundingfrustum
# horsesmultiply
# gammagot
# tweezerscurve
# dotwazzack
# realtorcaustic
# ledgeindeed
# dialgraft
# snowdonevasive
# ashamedmuscles
# blythpulse
# somethingalbedo
# feverspolystyrene
# carrionscream
# copalinstruct
# bunchmeats
# paddlevacuole
# horsesmultiply
# rigelpaunchy
# tendonwench
# meggingswine
# wordsundress
# eminentallergy
# sectionssqueaky
# pipeathlete
# globeshameful
# mtvgrosbeak
# applyingbaker
# moderatohorn
# craytugofwar
# binomialapathetic
# decanterbalance
# translatecyclist
# maintainwiggly
# somethingalbedo
# expecteffective
# ceilinjuries
# deficientclunking
# chichazard
# shrillbanjos
# crepegrape
# xslhopeful
# strungebay
# turnoverlovesick
# chichazard
# dampedbrioche
# frequencywould
# rigelpaunchy
# unguardedgiant
# xslhopeful
# dronessomersault
# epsiloncloning
# europiumcentury
# planktonuses
# rappelarias
# musicalchampagne
# showerspain
# eminentallergy
# tubingwheatear
# neckedjre
# burritoscarriage
# globeshameful
# producecoven
# wordsundress
# rubbishbladder
# replacedbevy
# gaudyfea
# showerspain
# farrowcetti
# geologybeeping
# croutonwrack
# bismuthcolloquial
# unicyclistamiable
# allegatorwafers
# gilletteclammy
# frequencywould
# cleaningburnt
# planktonuses
# freelysociable
# feverspolystyrene
# historypant
# tubingwheatear
# specifiedinnovative
# cowardlyabout
# handywrist
# loindecorate
# phobosstaccato
# dronessomersault
# historypant
# gravelscientific
# burritoscarriage
# babyambitious
# eminentallergy
# cranniescigarette
# hypergalaxyfibula
# earmarinated
# paddlevacuole
# cranniescigarette
# freelysociable
# organicmajor
# translatecyclist
# ischemicfrosted
# rappelarias
# ytterbiumprovincial
# tweezerscurve
# globeshameful
# flinkjordan
# cuboidpass
# fizzlehelp
# fizzlehelp
# micaassistant
# heaterinert
# gilletteclammy
# badgefields
# disjointtoday
# planktonuses
# tubingwheatear
# apronextension
# ceilinjuries
# crepegrape
# spiritedjump
# cheapersyllable
# stylishmugs
# binomialapathetic
# dampedbrioche
# somethingalbedo
# unbalancedprotoplanet
# chichazard
# chiselleddessicants
# rigelpaunchy
# hypergalaxyfibula
# buoyancycowardice
# cobolglaucous
# pipeathlete
# handywrist
# emeraldclippers
# realtorcaustic
# amuckpoints
# applyingbaker
# mincegaiters
# carrionscream
# deficientclunking
# alloweruptions
# spiritedjump
# gilletteclammy
# rigelpaunchy
# completionskylark
# trapdoormongrel
# cranesurgeon
# cheapersyllable
# shrillbanjos
# microwavejar
# wisefumbling
# chiselleddessicants
# gilletteclammy
# poundingfrustum
# burritoscarriage
# fizzclimbing
# paddlevacuole
# radicandoceanic
# trapdoormongrel
# bunchmeats
# turnoverlovesick
# somethingalbedo
# translatecyclist
# ytterbiumprovincial
# micaassistant
# fizzclimbing
# somethingalbedo
# heomicron
# eminentallergy
# figsql
# turnoverlovesick
# guavaconfide
# pancakesgrebe
# popmatrices
# phobosstaccato
# snowdonevasive
# ceilinjuries
# langeredsubset
# heaterinert
# chichazard
# gilletteclammy
# organicmajor
# horsesmultiply
# easybobolink
# cheapersyllable
# starbucksbluetail
# cleaningburnt
# planktonuses
# analbar
# tyrespan
# canalhateful
# expecteffective
# grabbig
# lasttaiga
# disjointtoday
# lickerbond
# twitequiver
# unbalancedprotoplanet
# quadratcranky
# eminentallergy
# looroasting
# globeshameful
# horsesmultiply
# impetuousfurbelows
# cleaningburnt
# specifiedinnovative
# bunchmeats
# risottospell
# backedammeter
# cranniescigarette
# musicalchampagne
# specifiedinnovative
# heaterinert
# gravelscientific
# sortinterior
# somethingalbedo
# copalinstruct
# cranniescigarette
# somethingalbedo
# completionskylark
# agenascientists
# gammagot
# looroasting
# opticsdiameter
# deficientclunking
# craytugofwar
# sociablelemma
# handywrist
# coatprecious
# gaudyfea
# ischemicfrosted
# cobolglaucous
# ledgeindeed
# bismuthcolloquial
# unbalancedprotoplanet
# globeshameful
# feverspolystyrene
# unguardedgiant
# gammagot
# dampedbrioche
# chichazard
# strungebay
# eontop
# maintainwiggly
# loindecorate
# gaudyfea
# cobolglaucous
# listenerabandoned
# historypant
# flakyunlawful
# synonympatisserie
# dotwazzack
# listenerabandoned
# earmarinated
# advisorlanguage
# hoovessquares
# submittedwavelength
# rigelpaunchy
# bunchmeats
# nursingrash
# ischemicfrosted
# handywrist
# handywrist
# hypergalaxyfibula
# phobosstaccato
# peacefulceaseless
# driftmvc
# peacefulceaseless
# handywrist
# stairsgobsmacked
# barnevidence
# bonelliseal
# bluetailgodwottery
# cleaningburnt
# bismuthcolloquial
# lasttaiga
# fundingticket
# chiselleddessicants
# axlevirtue
# deficientclunking
# snowdonevasive
# surmiseteenagers
# cartridgesbummage
# apronextension
# eminentallergy
# spiritedjump
# cobolglaucous
# musicalchampagne
# tweezerscurve
# strungebay
# backedammeter
# snaildossier
# looroasting
# actuallyfoot
# croutonwrack
# quadratcranky
# bunchmeats
# dotwazzack
# behaviourverbena
# canalhateful
# metaiota
# upbeatodd
# feverspolystyrene
# chichazard
# blythpulse
# eontop
# meatsoffbeat
# ashamedmuscles
# impetuousfurbelows
# farrowcetti
# allocatesposts
# looroasting
# mtvgrosbeak
# geologybeeping
# starbucksbluetail
# organicmajor
# impetuousfurbelows
# binomialapathetic
# poohvireo
# freelysociable
# evaporatingplug
# impetuousfurbelows
# sociablelemma
# chichazard
# wonderfulscullian
# micaassistant
# axlevirtue
# microwavejar
# europiumcentury
# rubbishbladder
# analbar
# paddlevacuole
# duexslt
# trapdoormongrel
# spiritedjump
# actuallyfoot
# buoyancycowardice
# blythpulse
# gravelscientific
# shrillbanjos
# simplicityfairy
# strungebay
# cobolglaucous
# turnoverlovesick
# ledgeindeed
# cuboidpass
# axlevirtue
# stunassured
# duexslt
# actuallyfoot
# snowdonevasive
# gaudyfea
# expecteffective
# hypergalaxyfibula
# twitequiver
# paddlevacuole
# chiselleddessicants
# organicmajor
# surmiseteenagers
# mtvgrosbeak
# ischemicfrosted
# gnarledbaggy
# swankythough
# looroasting
# canalhateful
# lickerbond
# troubledseptum
# actuallyfoot
# flickcanapes
# cuboidpass
# apronextension
# blythpulse
# burritoscarriage
# unicyclistamiable
# epsiloncloning
# fixnumquicklime
# organicmajor
# badgefields
# dweebspices
# disjointtoday
# coatprecious
# ellipticalfabricator
# musicalchampagne
# producecoven
# stunassured
# buoyancycowardice
# wordsundress
# tweezerscurve
# bonelliseal
# mtvgrosbeak
# snowdonevasive
# gruntdrive
# opticsdiameter
# twitequiver
# replacedbevy
# impetuousfurbelows
# swankythough
# metaiota
# copalinstruct
# blythpulse
# realtorcaustic
# binomialapathetic
# xslhopeful
# ischemicfrosted
# bismuthcolloquial
# producecoven
# mincegaiters
# evaporatingplug
# sectionssqueaky
# evaporatingplug
# ytterbiumprovincial
# bunchmeats
# stunassured
# showerspain
# dotwazzack
# heomicron
# chichazard
# microwavejar
# turnoverlovesick
# completionskylark
# axlevirtue
# bluetailgodwottery
# ytterbiumprovincial
# spiritedjump
# crepegrape
# namibianstabbing
# apronextension
# sortinterior
# somethingalbedo
# souffleutility
# craytugofwar
# shrillbanjos
# ceilinjuries
# micaassistant
# pancakesgrebe
# microwavejar
# babyambitious
# backedammeter
# swankythough
# easybobolink
# gilletteclammy
# bluetailgodwottery
# bunchmeats
# gogglesknacker
# binomialapathetic
# disjointtoday
# dialgraft
# latticelaboratory
# ledgeindeed
# buoyancycowardice
# disjointtoday
# producecoven
# paddlevacuole
# pipetsrockers
# musicalchampagne
# wonderfulscullian
# hypergalaxyfibula
# starbucksbluetail
# gaudyfea
# ytterbiumprovincial
# carrionscream
# burritoscarriage
# showerspain
# gammagot
# dampedbrioche
# tendonwench
# swankythough
# listenerabandoned
# neckedjre
# burntrifle
# cowardlyabout
# horsesmultiply
# synonympatisserie
# fizzclimbing
# starbucksbluetail
# hypergalaxyfibula
# musicalchampagne
# gruntdrive
# behaviourverbena
# historypant
# rubbishbladder
# bluetailgodwottery
# shrillbanjos
# tendonwench
# namibianstabbing
# easybobolink
# ellipticalfabricator
# unguardedgiant
# unbalancedprotoplanet
# croutonwrack
# gnarledbaggy
# grabbig
# crepegrape
# singesculptor
# cuboidpass
# rigelpaunchy
# tubingwheatear
# latticelaboratory
# ceilinjuries
# deficientclunking
# quadratcranky
# pleasinghoop
# moderatohorn
# latticelaboratory
# spiritedjump
# spiritedjump
# farrowcetti
# historypant
# driftmvc
# smackswallow
# tyrespan
# farrowcetti
# figsql
# pancakesgrebe
# lymphomamellow
# submittedwavelength
# risottospell
# axlevirtue
# easybobolink
# badgefields
# gaudyfea
# sortinterior
# sectionssqueaky
# gilletteclammy
# analbar
# peacefulceaseless
# surmiseteenagers
# dronessomersault
# microwavejar
# paddlevacuole
# clucklinnet
# sortinterior
# amuckpoints
# stairsgobsmacked
# wordsundress
# burntrifle
# trapdoormongrel
# wordsundress
# neckedjre
# compareas
# ellipticalfabricator
# applyingbaker
# neckedjre
# cranesurgeon
# farrowcetti
# barnevidence
# surmiseteenagers
# figsql
# carrionscream
# bluetailgodwottery
# sectionssqueaky
# deficientclunking
# cobolglaucous
# simplicityfairy
# mincegaiters
# langeredsubset
# unicyclistamiable
# upbeatodd
# frequencywould
# poohvireo
# analbar
# peacefulceaseless
# disjointtoday
# coatprecious
# cranniescigarette
# applyingbaker
# ytterbiumprovincial
# advisorlanguage
# feverspolystyrene
# easybobolink
# dampedbrioche
# unicyclistamiable
# latticelaboratory
# wordsundress
# raggedshrink
# peacefulceaseless
# barnevidence
# planktonuses
# namibianstabbing
# looroasting
# bluetailgodwottery
# farrowcetti
# looroasting
# hoursethanoate
# pipeathlete
# unguardedgiant
# driftmvc
# driftmvc
# gravelscientific
# smackswallow
# flickcanapes
# looroasting
# tubingwheatear
# expecteffective
# neckedjre
# wordsundress
# unicyclistamiable
# driftmvc
# flickcanapes
# fattyoddball
# metaiota
# tyrespan
# replacedbevy
# gruntdrive
# singesculptor
# geologybeeping
# babyambitious
# driftmvc
# cartridgesbummage
# alloweruptions
# cowardlyabout
# neighborlyrook
# phobosstaccato
# ledgeindeed
# singesculptor
# belchedsodding
# stylishmugs
# gammagot
# alloweruptions
# souffleutility
# behaveterminal
# decanterbalance
# ytterbiumprovincial
# figsql
# hypergalaxyfibula
# globeshameful
# chiselleddessicants
# meatsoffbeat
# cowardlyabout
# microwavejar
# phobosstaccato
# compareas
# namibianstabbing
# ledgeindeed
# ischemicfrosted
# peacefulceaseless
# behaveterminal
# tendonwench
# europiumcentury
# ceilinjuries
# hoovessquares
# parallelconcerned
# smackswallow
# producecoven
# batchquickest
# rappelarias
# globeshameful
# starbucksbluetail
# applyingbaker
# lasttaiga
# sectionssqueaky
# flakyunlawful
# duexslt
# tweezerscurve
# dotwazzack
# cuboidpass
# rubbishbladder
# parallelconcerned
# globeshameful
# croutonwrack
# micaassistant
# carrionscream
# privacyhaunt
# alloweruptions
# babyambitious
# eminentallergy
# copalinstruct
# hoursethanoate
# chichazard
# applyingbaker
# analbar
# cranesurgeon
# gogglesknacker
# translatecyclist
# amuckpoints
# wisefumbling
# axlevirtue
# hoursethanoate
# moderatohorn
# swankythough
# cheapersyllable
# troubledseptum
# simplicityfairy
# risottospell
# swankythough
# meatsoffbeat
# duexslt
# wisefumbling
# freelysociable
# specifiedinnovative
# lickerbond
# flickcanapes
# flickcanapes
# applyingbaker
# completionskylark
# grabbig
# rigelpaunchy
# analbar
# strungebay
# alloweruptions
# musicalchampagne
# hoovessquares
# historypant
# showerspain
# hoursethanoate
# historypant
# latticelaboratory
# poundingfrustum
# specifiedinnovative
# dampedbrioche
# meatsoffbeat
# quadratcranky
# europiumcentury
# deficientclunking
# heaterinert
# alloweruptions
# swankythough
# globeshameful
# carrionscream
# bismuthcolloquial
# turnoverlovesick
# flinkjordan
# moderatohorn
# duexslt
# submittedwavelength
# gaudyfea
# dialgraft
# cleaningburnt
# amuckpoints
# stairsgobsmacked
# carrionscream
# submittedwavelength
# coatprecious
# globeshameful
# neckedjre
# quadratcranky
# rubbishbladder
# cartridgesbummage
# applyingbaker
# shrillbanjos
# flinkjordan
# casesslippery
# stairsgobsmacked
# earmarinated
# epsiloncloning
# frequencywould
# upbeatodd
# tubingwheatear
# fizzclimbing
# quadratcranky
# europiumcentury
# showerspain
# mincegaiters
# flinkjordan
# figsql
# somethingalbedo
# behaviourverbena
# blythpulse
# bonelliseal
# behaveterminal
# ytterbiumprovincial
# gogglesknacker
# synonympatisserie
# impetuousfurbelows
# buoyancycowardice
# tweezerscurve
# copalinstruct
# realtorcaustic
# stairsgobsmacked
# grabbig
# sociablelemma
# gilletteclammy
# ashamedmuscles
# sociablelemma
# spiritedjump
# upbeatodd
# impetuousfurbelows
# advisorlanguage
# stunassured
# rubbishbladder
# smackswallow
# dotwazzack
# risottospell
# dampedbrioche
# surmiseteenagers
# lasttaiga
# tweezerscurve
# freelysociable
# europiumcentury
# neighborlyrook
# eminentallergy
# souffleutility
# maintainwiggly
# meggingswine
# dotwazzack
# worldlyventuri
# bracesworkable
# analbar
# eontop
# looroasting
# replacedbevy
# dweebspices
# burritoscarriage
# gaudyfea
# alloweruptions
# evaporatingplug
# epsiloncloning
# gravelscientific
# strungebay
# poundingfrustum
# microwavejar
# snaildossier
# geologybeeping
# easybobolink
# tweezerscurve
# barnevidence
# ledgeindeed
# buoyancycowardice
# lickerbond
# langeredsubset
# flinkjordan
# crepegrape
# fattyoddball
# frequencywould
# privacyhaunt
# tweezerscurve
# flakyunlawful
# realtorcaustic
# parallelconcerned
# pipeathlete
# heomicron
# dronessomersault
# cuboidpass
# realtorcaustic
# dweebspices
# nursingrash
# realtorcaustic
# cranniescigarette
# flinkjordan
# nursingrash
# completionskylark
# impetuousfurbelows
# phobosstaccato
# epsiloncloning
# gogglesknacker
# badgefields
# dotwazzack
# lickerbond
# tweezerscurve
# canalhateful
# snaildossier
# worldlyventuri
# decanterbalance
# canalhateful
# somethingalbedo
# opticsdiameter
# dampedbrioche
# bluetailgodwottery
# handywrist
# poundingfrustum
# meggingswine
# gruntdrive
# flakyunlawful
# barnevidence
# feverspolystyrene
# burntrifle
# flakyunlawful
# grabbig
# completionskylark
# globeshameful
# epsiloncloning
# pipeathlete
# dialgraft
# rubbishbladder
# dronessomersault
# epsiloncloning
# gnarledbaggy
# europiumcentury
# bashrower
# feverspolystyrene
# tubingwheatear
# allegatorwafers
# poundingfrustum
# expecteffective
# backedammeter
# pancakesgrebe
# flickcanapes
# gaudyfea
# mincegaiters
# quadratcranky
# duexslt
# gogglesknacker
# snowdonevasive
# completionskylark
# ashamedmuscles
# stunassured
# feverspolystyrene
# ellipticalfabricator
# trapdoormongrel
# easybobolink
# rubbishbladder
# behaveterminal
# canalhateful
# dotwazzack
# dampedbrioche
# babyambitious
# snaildossier
# completionskylark
# ledgeindeed
# mincegaiters
# coatprecious
# pleasinghoop
# fundingticket
# behaviourverbena
# agenascientists
# fixnumquicklime
# burritoscarriage
# axlevirtue
# tweezerscurve
# eontop
# behaviourverbena
# compareas
# crepegrape
# strungebay
# cowardlyabout
# amuckpoints
# somethingalbedo
# dronessomersault
# decanterbalance
# stunassured
# pleasinghoop
# guavaconfide
# gammagot
# cobolglaucous
# belchedsodding
# handywrist
# casesslippery
# deficientclunking
# cowardlyabout
# privacyhaunt
# worldlyventuri
# historypant
# europiumcentury
# translatecyclist
# wisefumbling
# swankythough
# gilletteclammy
# dronessomersault
# planktonuses
# parallelconcerned
# planktonuses
# farrowcetti
# behaviourverbena
# ischemicfrosted
# realtorcaustic
# fundingticket
# figsql
# badgefields
# geologybeeping
# sociablelemma
# behaviourverbena
# mincegaiters
# handywrist
# applyingbaker
# completionskylark
# actuallyfoot
# spiritedjump
# fattyoddball
# micaassistant
# ceilinjuries
# stairsgobsmacked
# globeshameful
# wordsundress
# belchedsodding
# grabbig
# micaassistant
# batchquickest
# bunchmeats
# langeredsubset
# fizzlehelp
# alloweruptions
# gnarledbaggy
# grabbig
# advisorlanguage
# guavaconfide
# gammagot
# heaterinert
# gnarledbaggy
# buoyancycowardice
# bashrower
# moderatohorn
# langeredsubset
# stylishmugs
# fundingticket
# ellipticalfabricator
# showerspain
# emeraldclippers
# cartridgesbummage
# ceilinjuries
# mtvgrosbeak
# compareas
# canalhateful
# belchedsodding
# namibianstabbing
# carrionscream
# dotwazzack
# earmarinated
# singesculptor
# analbar
# apronextension
# gnarledbaggy
# unbalancedprotoplanet
# worldlyventuri
# cartridgesbummage
# globeshameful
# earmarinated
# grabbig
# blythpulse
# eminentallergy
# driftmvc
# shrillbanjos
# horsesmultiply
# eontop
# cartridgesbummage
# crepegrape
# raggedshrink
# instantthwack
# clucklinnet
# bunchmeats
# namibianstabbing
# poundingfrustum
# latticelaboratory
# lymphomamellow
# blythpulse
# ashamedmuscles
# backedammeter
# impetuousfurbelows
# gogglesknacker
# ceilinjuries
# ledgeindeed
# somethingalbedo
# carrionscream
# unbalancedprotoplanet
# gnarledbaggy
# gammagot
# gravelscientific
# epsiloncloning
# nursingrash
# backedammeter
# ceilinjuries
# looroasting
# epsiloncloning
# applyingbaker
# bashrower
# translatecyclist
# copalinstruct
# dialgraft
# dialgraft
# bismuthcolloquial
# sectionssqueaky
# fixnumquicklime
# swankythough
# cranniescigarette
# cheapersyllable
# cranniescigarette
# troubledseptum
# easybobolink
# backedammeter
# unicyclistamiable
# dialgraft
# namibianstabbing
# nursingrash
# alloweruptions
# emeraldclippers
# feverspolystyrene
# easybobolink
# somethingalbedo
# raggedshrink
# twitequiver
# carrionscream
# barnevidence
# compareas
# impetuousfurbelows
# tendonwench
# evaporatingplug
# barnevidence
# flickcanapes
# planktonuses
# handywrist
# hypergalaxyfibula
# decanterbalance
# behaveterminal
# snowdonevasive
# pipetsrockers
# decanterbalance
# tweezerscurve
# decanterbalance
# rappelarias
# ceilinjuries
# hoursethanoate
# radicandoceanic
# gravelscientific
# replacedbevy
# stairsgobsmacked
# behaveterminal
# fattyoddball
# snowdonevasive
# chichazard
# ellipticalfabricator
# freelysociable
# cranesurgeon
# neighborlyrook
# europiumcentury
# fizzclimbing
# babyambitious
# simplicityfairy
# unbalancedprotoplanet
# simplicityfairy
# compareas
# grabbig
# impetuousfurbelows
# xslhopeful
# swankythough
# maintainwiggly
# carrionscream
# axlevirtue
# hypergalaxyfibula
# instantthwack
# souffleutility
# worldlyventuri
# replacedbevy
# meatsoffbeat
# gruntdrive
# driftmvc
# upbeatodd
# xslhopeful
# ledgeindeed
# casesslippery
# canalhateful
# cartridgesbummage
# easybobolink
# lymphomamellow
# crepegrape
# barnevidence
# sortinterior
# lymphomamellow
# disjointtoday
# driftmvc
# realtorcaustic
# ledgeindeed
# deficientclunking
# starbucksbluetail
# elatedunicorn
# fundingticket
# geologybeeping
# flinkjordan
# earmarinated
# ischemicfrosted
# risottospell
# coatprecious
# wonderfulscullian
# gnarledbaggy
# amuckpoints
# axlevirtue
# cranesurgeon
# bluetailgodwottery
# sectionssqueaky
# surmiseteenagers
# upbeatodd
# singesculptor
# backedammeter
# ceilinjuries
# belchedsodding
# gilletteclammy
# shrillbanjos
# figsql
# cranesurgeon
# figsql
# latticelaboratory
# carrionscream
# neighborlyrook
# loindecorate
# dotwazzack
# turnoverlovesick
# farrowcetti
# looroasting
# flickcanapes
# behaviourverbena
# hoursethanoate
# lasttaiga
# buoyancycowardice
# fizzclimbing
# applyingbaker
# driftmvc
# elatedunicorn
# geologybeeping
# peacefulceaseless
# xslhopeful
# ledgeindeed
# pipeathlete
# barnevidence
# cranesurgeon
# historypant
# organicmajor
# compareas
# allegatorwafers
# paddlevacuole
# shrillbanjos
# peacefulceaseless
# wordsundress
# shrillbanjos
# cheapersyllable
# apronextension
# lymphomamellow
# grabbig
# burritoscarriage
# privacyhaunt
# loindecorate
# stunassured
# spiritedjump
# rigelpaunchy
# lickerbond
# snowdonevasive
# starbucksbluetail
# globeshameful
# flickcanapes
# heomicron
# canalhateful
# cleaningburnt
# lasttaiga
# lasttaiga
# instantthwack
# upbeatodd
# evaporatingplug
# gaudyfea
# loindecorate
# casesslippery
# unbalancedprotoplanet
# organicmajor
# batchquickest
# backedammeter
# nursingrash
# parallelconcerned
# rappelarias
# fizzclimbing
# lickerbond
# ceilinjuries
# looroasting
# belchedsodding
# babyambitious
# smackswallow
# flakyunlawful
# specifiedinnovative
# fattyoddball
# coatprecious
# somethingalbedo
# bismuthcolloquial
# souffleutility
# cranniescigarette
# deficientclunking
# cobolglaucous
# gravelscientific
# planktonuses
# deficientclunking
# guavaconfide
# cheapersyllable
# neighborlyrook
# sectionssqueaky
# unicyclistamiable
# stunassured
# somethingalbedo
# spiritedjump
# driftmvc
# bismuthcolloquial
# stylishmugs
# belchedsodding
# dialgraft
# poundingfrustum
# colonclipper
# clucklinnet
# belchedsodding
# globeshameful
# privacyhaunt
# neighborlyrook
# actuallyfoot
# wisefumbling
# ischemicfrosted
# mtvgrosbeak
# popmatrices
# starbucksbluetail
# loindecorate
# risottospell
# tubingwheatear
# compareas
# clucklinnet
# duexslt
# neckedjre
# evaporatingplug
# musicalchampagne
# cranesurgeon
# lasttaiga
# bismuthcolloquial
# evaporatingplug
# pancakesgrebe
# buoyancycowardice
# fundingticket
# duexslt
# decanterbalance
# stunassured
# translatecyclist
# burritoscarriage
# fizzclimbing
# bonelliseal
# loindecorate
# easybobolink
# ...
# wisefumbling
# fattyoddball
# elatedunicorn
# unbalancedprotoplanet
# frequencywould
# swankythough
# cuboidpass
# grabbig
# duexslt
# realtorcaustic
# microwavejar
# canalhateful
# wisefumbling
# moderatohorn
# amuckpoints
# chiselleddessicants
# ytterbiumprovincial
# frequencywould
# stylishmugs
# upbeatodd
# cartridgesbummage
# tubingwheatear
# expecteffective
# badgefields
# eminentallergy
# ashamedmuscles
# neckedjre
# somethingalbedo
# easybobolink
# earmarinated
# handywrist
# craytugofwar
# bonelliseal
# belchedsodding
# ellipticalfabricator
# decanterbalance
# upbeatodd
# worldlyventuri
# dampedbrioche
# alloweruptions
# cranesurgeon
# copalinstruct
# flinkjordan
# phobosstaccato
# badgefields
# buoyancycowardice
# cheapersyllable
# disjointtoday
# amuckpoints
# stunassured
# pipetsrockers
# translatecyclist
# micaassistant
# meggingswine
# ashamedmuscles
# neighborlyrook
# ashamedmuscles
# tyrespan
# craytugofwar
# actuallyfoot
# eontop
# radicandoceanic
# elatedunicorn
# poohvireo
# lickerbond
# surmiseteenagers
# driftmvc
# fundingticket
# behaveterminal
# synonympatisserie
# ischemicfrosted
# decanterbalance
# cheapersyllable
# epsiloncloning
# frequencywould
# pipetsrockers
# popmatrices
# grabbig
# gogglesknacker
# buoyancycowardice
# alloweruptions
# freelysociable
# neckedjre
# translatecyclist
# clucklinnet
# compareas
# planktonuses
# peacefulceaseless
# ytterbiumprovincial
# bunchmeats
# mtvgrosbeak
# easybobolink
# backedammeter
# eminentallergy
# lymphomamellow
# driftmvc
# twitequiver
# ischemicfrosted
# flickcanapes
# rigelpaunchy
# metaiota
# snowdonevasive
# snaildossier
# realtorcaustic
# feverspolystyrene
# eminentallergy
# evaporatingplug
# snaildossier
# popmatrices
# hoovessquares
# pipetsrockers
# unguardedgiant
# decanterbalance
# horsesmultiply
# cowardlyabout
# neckedjre
# gammagot
# planktonuses
# upbeatodd
# gruntdrive
# advisorlanguage
# ashamedmuscles
# expecteffective
# producecoven
# neighborlyrook
# instantthwack
# belchedsodding
# unguardedgiant
# sectionssqueaky
# cuboidpass
# twitequiver
# impetuousfurbelows
# ledgeindeed
# smackswallow
# unicyclistamiable
# compareas
# loindecorate
# ceilinjuries
# snowdonevasive
# opticsdiameter
# planktonuses
# mtvgrosbeak
# ashamedmuscles
# dotwazzack
# stunassured
# rigelpaunchy
# binomialapathetic
# axlevirtue
# globeshameful
# eontop
# duexslt
# carrionscream
# dotwazzack
# dotwazzack
# maintainwiggly
# epsiloncloning
# blythpulse
# maintainwiggly
# poohvireo
# disjointtoday
# troubledseptum
# dronessomersault
# cuboidpass
# stylishmugs
# carrionscream
# producecoven
# compareas
# maintainwiggly
# wisefumbling
# historypant
# tubingwheatear
# xslhopeful
# stairsgobsmacked
# twitequiver
# paddlevacuole
# epsiloncloning
# ytterbiumprovincial
# metaiota
# specifiedinnovative
# replacedbevy
# rigelpaunchy
# actuallyfoot
# ytterbiumprovincial
# flakyunlawful
# globeshameful
# eminentallergy
# raggedshrink
# ashamedmuscles
# horsesmultiply
# planktonuses
# figsql
# souffleutility
# unicyclistamiable
# meatsoffbeat
# showerspain
# musicalchampagne
# microwavejar
# cowardlyabout
# driftmvc
# neckedjre
# surmiseteenagers
# unguardedgiant
# gilletteclammy
# coatprecious
# neckedjre
# fattyoddball
# moderatohorn
# easybobolink
# clucklinnet
# casesslippery
# burntrifle
# gammagot
# fundingticket
# behaviourverbena
# namibianstabbing
# simplicityfairy
# actuallyfoot
# applyingbaker
# deficientclunking
# showerspain
# cranesurgeon
# troubledseptum
# replacedbevy
# realtorcaustic
# langeredsubset
# carrionscream
# souffleutility
# gogglesknacker
# unguardedgiant
# cowardlyabout
# simplicityfairy
# ellipticalfabricator
# ledgeindeed
# gammagot
# colonclipper
# smackswallow
# submittedwavelength
# meatsoffbeat
# canalhateful
# cleaningburnt
# hoovessquares
# twitequiver
# rigelpaunchy
# hoovessquares
# nursingrash
# wonderfulscullian
# twitequiver
# cleaningburnt
# synonympatisserie
# analbar
# neckedjre
# behaviourverbena
# epsiloncloning
# historypant
# behaviourverbena
# heomicron
# barnevidence
# disjointtoday
# axlevirtue
# spiritedjump
# lymphomamellow
# amuckpoints
# popmatrices
# fizzclimbing
# souffleutility
# burntrifle
# strungebay
# apronextension
# peacefulceaseless
# bunchmeats
# chiselleddessicants
# hoursethanoate
# cranniescigarette
# gruntdrive
# pancakesgrebe
# ledgeindeed
# horsesmultiply
# cranniescigarette
# langeredsubset
# impetuousfurbelows
# sortinterior
# amuckpoints
# heomicron
# mincegaiters
# apronextension
# wisefumbling
# trapdoormongrel
# ellipticalfabricator
# carrionscream
# translatecyclist
# pleasinghoop
# tyrespan
# twitequiver
# colonclipper
# deficientclunking
# swankythough
# burritoscarriage
# flakyunlawful
# easybobolink
# coatprecious
# expecteffective
# troubledseptum
# upbeatodd
# submittedwavelength
# troubledseptum
# upbeatodd
# listenerabandoned
# phobosstaccato
# ellipticalfabricator
# starbucksbluetail
# risottospell
# batchquickest
# feverspolystyrene
# musicalchampagne
# fizzclimbing
# fizzlehelp
# emeraldclippers
# handywrist
# mtvgrosbeak
# horsesmultiply
# easybobolink
# sociablelemma
# specifiedinnovative
# twitequiver
# privacyhaunt
# tweezerscurve
# translatecyclist
# colonclipper
# burritoscarriage
# translatecyclist
# stairsgobsmacked
# clucklinnet
# ashamedmuscles
# unbalancedprotoplanet
# eontop
# poundingfrustum
# stunassured
# ytterbiumprovincial
# lasttaiga
# specifiedinnovative
# producecoven
# belchedsodding
# completionskylark
# unguardedgiant
# duexslt
# advisorlanguage
# binomialapathetic
# ytterbiumprovincial
# gnarledbaggy
# emeraldclippers
# chichazard
# strungebay
# backedammeter
# fizzclimbing
# chichazard
# tweezerscurve
# ischemicfrosted
# maintainwiggly
# lickerbond
# bonelliseal
# cleaningburnt
# decanterbalance
# alloweruptions
# easybobolink
# horsesmultiply
# popmatrices
# coatprecious
# phobosstaccato
# amuckpoints
# globeshameful
# trapdoormongrel
# fizzlehelp
# backedammeter
# bashrower
# gammagot
# advisorlanguage
# duexslt
# translatecyclist
# radicandoceanic
# advisorlanguage
# emeraldclippers
# fundingticket
# agenascientists
# parallelconcerned
# farrowcetti
# risottospell
# unicyclistamiable
# evaporatingplug
# figsql
# instantthwack
# cleaningburnt
# hypergalaxyfibula
# risottospell
# simplicityfairy
# heaterinert
# sectionssqueaky
# poohvireo
# frequencywould
# cranniescigarette
# easybobolink
# rigelpaunchy
# allegatorwafers
# epsiloncloning
# ledgeindeed
# lasttaiga
# cleaningburnt
# earmarinated
# cowardlyabout
# bracesworkable
# ytterbiumprovincial
# peacefulceaseless
# duexslt
# heaterinert
# singesculptor
# swankythough
# advisorlanguage
# deficientclunking
# pipetsrockers
# copalinstruct
# ashamedmuscles
# stairsgobsmacked
# canalhateful
# worldlyventuri
# smackswallow
# guavaconfide
# pipetsrockers
# blythpulse
# impetuousfurbelows
# copalinstruct
# impetuousfurbelows
# cowardlyabout
# paddlevacuole
# unicyclistamiable
# burntrifle
# stairsgobsmacked
# producecoven
# poundingfrustum
# paddlevacuole
# moderatohorn
# rubbishbladder
# croutonwrack
# agenascientists
# croutonwrack
# bluetailgodwottery
# craytugofwar
# expecteffective
# heomicron
# phobosstaccato
# actuallyfoot
# croutonwrack
# dweebspices
# gaudyfea
# feverspolystyrene
# disjointtoday
# namibianstabbing
# shrillbanjos
# strungebay
# emeraldclippers
# hypergalaxyfibula
# translatecyclist
# gogglesknacker
# surmiseteenagers
# singesculptor
# producecoven
# pleasinghoop
# craytugofwar
# completionskylark
# replacedbevy
# dotwazzack
# planktonuses
# privacyhaunt
# disjointtoday
# simplicityfairy
# sectionssqueaky
# lasttaiga
# ytterbiumprovincial
# mtvgrosbeak
# producecoven
# freelysociable
# gravelscientific
# swankythough
# behaveterminal
# flakyunlawful
# phobosstaccato
# synonympatisserie
# dampedbrioche
# snaildossier
# applyingbaker
# pipetsrockers
# duexslt
# pleasinghoop
# radicandoceanic
# cheapersyllable
# flickcanapes
# pipeathlete
# tweezerscurve
# belchedsodding
# bluetailgodwottery
# tweezerscurve
# ellipticalfabricator
# gogglesknacker
# gruntdrive
# surmiseteenagers
# badgefields
# unbalancedprotoplanet
# twitequiver
# advisorlanguage
# cartridgesbummage
# musicalchampagne
# souffleutility
# looroasting
# farrowcetti
# cuboidpass
# quadratcranky
# bonelliseal
# pipeathlete
# poundingfrustum
# gaudyfea
# souffleutility
# stylishmugs
# swankythough
# meatsoffbeat
# impetuousfurbelows
# upbeatodd
# apronextension
# chichazard
# popmatrices
# popmatrices
# opticsdiameter
# lickerbond
# flickcanapes
# cartridgesbummage
# globeshameful
# coatprecious
# raggedshrink
# namibianstabbing
# gruntdrive
# shrillbanjos
# bonelliseal
# dweebspices
# cranniescigarette
# organicmajor
# musicalchampagne
# radicandoceanic
# fizzclimbing
# souffleutility
# pancakesgrebe
# microwavejar
# privacyhaunt
# flakyunlawful
# horsesmultiply
# batchquickest
# completionskylark
# hoursethanoate
# copalinstruct
# feverspolystyrene
# freelysociable
# cheapersyllable
# expecteffective
# compareas
# decanterbalance
# burritoscarriage
# gilletteclammy
# wisefumbling
# emeraldclippers
# lasttaiga
# gaudyfea
# eminentallergy
# poohvireo
# somethingalbedo
# blythpulse
# paddlevacuole
# popmatrices
# translatecyclist
# quadratcranky
# evaporatingplug
# pleasinghoop
# flinkjordan
# producecoven
# bismuthcolloquial
# flinkjordan
# souffleutility
# backedammeter
# meggingswine
# ellipticalfabricator
# microwavejar
# unguardedgiant
# neckedjre
# heaterinert
# sociablelemma
# gnarledbaggy
# looroasting
# synonympatisserie
# bashrower
# babyambitious
# disjointtoday
# phobosstaccato
# cobolglaucous
# axlevirtue
# hoursethanoate
# horsesmultiply
# easybobolink
# ceilinjuries
# hoursethanoate
# spiritedjump
# axlevirtue
# singesculptor
# microwavejar
# twitequiver
# epsiloncloning
# gilletteclammy
# gnarledbaggy
# deficientclunking
# shrillbanjos
# eminentallergy
# buoyancycowardice
# bismuthcolloquial
# simplicityfairy
# twitequiver
# applyingbaker
# horsesmultiply
# allocatesposts
# stylishmugs
# handywrist
# emeraldclippers
# binomialapathetic
# pipetsrockers
# babyambitious
# decanterbalance
# flickcanapes
# frequencywould
# driftmvc
# advisorlanguage
# babyambitious
# smackswallow
# bracesworkable
# apronextension
# babyambitious
# flinkjordan
# advisorlanguage
# hoursethanoate
# cranesurgeon
# sociablelemma
# elatedunicorn
# binomialapathetic
# snaildossier
# wordsundress
# quadratcranky
# popmatrices
# shrillbanjos
# badgefields
# ledgeindeed
# pipetsrockers
# moderatohorn
# cleaningburnt
# souffleutility
# fizzclimbing
# geologybeeping
# gruntdrive
# burntrifle
# gaudyfea
# worldlyventuri
# pipeathlete
# bashrower
# pleasinghoop
# quadratcranky
# poohvireo
# looroasting
# ceilinjuries
# unicyclistamiable
# trapdoormongrel
# heaterinert
# gaudyfea
# loindecorate
# latticelaboratory
# allocatesposts
# troubledseptum
# tendonwench
# snowdonevasive
# cranesurgeon
# snaildossier
# rappelarias
# easybobolink
# europiumcentury
# chiselleddessicants
# namibianstabbing
# croutonwrack
# grabbig
# batchquickest
# badgefields
# simplicityfairy
# cleaningburnt
# troubledseptum
# coatprecious
# meggingswine
# clucklinnet
# batchquickest
# bashrower
# dronessomersault
# easybobolink
# colonclipper
# unguardedgiant
# eminentallergy
# souffleutility
# pipeathlete
# gnarledbaggy
# synonympatisserie
# advisorlanguage
# lasttaiga
# apronextension
# bracesworkable
# turnoverlovesick
# behaveterminal
# amuckpoints
# bluetailgodwottery
# bluetailgodwottery
# cowardlyabout
# coatprecious
# mtvgrosbeak
# figsql
# dweebspices
# bismuthcolloquial
# hypergalaxyfibula
# eontop
# namibianstabbing
# flakyunlawful
# bunchmeats
# cleaningburnt
# poundingfrustum
# handywrist
# flinkjordan
# coatprecious
# nursingrash
# actuallyfoot
# wonderfulscullian
# trapdoormongrel
# bluetailgodwottery
# flakyunlawful
# behaviourverbena
# flinkjordan
# emeraldclippers
# trapdoormongrel
# producecoven
# snaildossier
# starbucksbluetail
# starbucksbluetail
# cuboidpass
# evaporatingplug
# unguardedgiant
# copalinstruct
# bluetailgodwottery
# risottospell
# badgefields
# snaildossier
# submittedwavelength
# translatecyclist
# easybobolink
# musicalchampagne
# gammagot
# crepegrape
# parallelconcerned
# burritoscarriage
# dampedbrioche
# starbucksbluetail
# neckedjre
# realtorcaustic
# fundingticket
# gnarledbaggy
# hoursethanoate
# specifiedinnovative
# advisorlanguage
# decanterbalance
# wonderfulscullian
# bismuthcolloquial
# copalinstruct
# bonelliseal
# badgefields
# compareas
# canalhateful
# wordsundress
# risottospell
# burntrifle
# horsesmultiply
# fizzlehelp
# dronessomersault
# evaporatingplug
# freelysociable
# heomicron
# submittedwavelength
# sectionssqueaky
# turnoverlovesick
# dotwazzack
# casesslippery
# decanterbalance
# expecteffective
# translatecyclist
# axlevirtue
# twitequiver
# heaterinert
# quadratcranky
# showerspain
# ellipticalfabricator
# maintainwiggly
# handywrist
# frequencywould
# worldlyventuri
# maintainwiggly
# crepegrape
# analbar
# ellipticalfabricator
# fizzlehelp
# freelysociable
# expecteffective
# parallelconcerned
# binomialapathetic
# hoursethanoate
# stunassured
# globeshameful
# badgefields
# copalinstruct
# alloweruptions
# gilletteclammy
# privacyhaunt
# croutonwrack
# grabbig
# organicmajor
# ashamedmuscles
# pipeathlete
# ashamedmuscles
# metaiota
# cheapersyllable
# actuallyfoot
# spiritedjump
# flinkjordan
# casesslippery
# emeraldclippers
# langeredsubset
# cowardlyabout
# wordsundress
# specifiedinnovative
# instantthwack
# realtorcaustic
# epsiloncloning
# globeshameful
# hypergalaxyfibula
# quadratcranky
# meatsoffbeat
# clucklinnet
# freelysociable
# belchedsodding
# hoursethanoate
# pancakesgrebe
# opticsdiameter
# craytugofwar
# hypergalaxyfibula
# singesculptor
# unguardedgiant
# frequencywould
# privacyhaunt
# apronextension
# unbalancedprotoplanet
# snowdonevasive
# ashamedmuscles
# xslhopeful
# fattyoddball
# turnoverlovesick
# phobosstaccato
# deficientclunking
# ellipticalfabricator
# peacefulceaseless
# bracesworkable
# strungebay
# sortinterior
# dampedbrioche
# bunchmeats
# unguardedgiant
# guavaconfide
# snowdonevasive
# burritoscarriage
# radicandoceanic
# alloweruptions
# casesslippery
# producecoven
# troubledseptum
# flickcanapes
# flinkjordan
# tweezerscurve
# producecoven
# completionskylark
# bashrower
# epsiloncloning
# instantthwack
# compareas
# impetuousfurbelows
# privacyhaunt
# looroasting
# microwavejar
# impetuousfurbelows
# planktonuses
# raggedshrink
# behaveterminal
# ledgeindeed
# colonclipper
# radicandoceanic
# expecteffective
# lasttaiga
# tubingwheatear
# ellipticalfabricator
# bluetailgodwottery
# risottospell
# behaveterminal
# lymphomamellow
# hoovessquares
# lasttaiga
# blythpulse
# pipeathlete
# clucklinnet
# somethingalbedo
# fattyoddball
# upbeatodd
# hoovessquares
# flakyunlawful
# microwavejar
# cowardlyabout
# disjointtoday
# figsql
# amuckpoints
# trapdoormongrel
# figsql
# burritoscarriage
# clucklinnet
# clucklinnet
# bunchmeats
# snaildossier
# namibianstabbing
# listenerabandoned
# lasttaiga
# eminentallergy
# looroasting
# babyambitious
# fixnumquicklime
# trapdoormongrel
# fixnumquicklime
# micaassistant
# badgefields
# bracesworkable
# snowdonevasive
# xslhopeful
# loindecorate
# pipetsrockers
# tubingwheatear
# ashamedmuscles
# gaudyfea
# alloweruptions
# actuallyfoot
# copalinstruct
# cheapersyllable
# disjointtoday
# grabbig
# cheapersyllable
# hoovessquares
# hypergalaxyfibula
# translatecyclist
# barnevidence
# unicyclistamiable
# blythpulse
# producecoven
# stylishmugs
# driftmvc
# eontop
# burntrifle
# burntrifle
# planktonuses
# pipetsrockers
# spiritedjump
# poohvireo
# horsesmultiply
# surmiseteenagers
# planktonuses
# barnevidence
# clucklinnet
# radicandoceanic
# simplicityfairy
# sectionssqueaky
# ellipticalfabricator
# ceilinjuries
# dweebspices
# alloweruptions
# easybobolink
# blythpulse
# flinkjordan
# turnoverlovesick
# elatedunicorn
# globeshameful
# gaudyfea
# spiritedjump
# copalinstruct
# singesculptor
# clucklinnet
# flickcanapes
# flakyunlawful
# fizzclimbing
# gaudyfea
# burntrifle
# planktonuses
# evaporatingplug
# rigelpaunchy
# badgefields
# neckedjre
# sociablelemma
# unbalancedprotoplanet
# actuallyfoot
# fizzlehelp
# flickcanapes
# snowdonevasive
# sociablelemma
# alloweruptions
# sociablelemma
# earmarinated
# bluetailgodwottery
# looroasting
# completionskylark
# bunchmeats
# batchquickest
# cobolglaucous
# pancakesgrebe
# agenascientists
# somethingalbedo
# heomicron
# organicmajor
# latticelaboratory
# sortinterior
# easybobolink
# producecoven
# badgefields
# ashamedmuscles
# bonelliseal
# pancakesgrebe
# bonelliseal
# specifiedinnovative
# driftmvc
# burntrifle
# analbar
# craytugofwar
# smackswallow
# cartridgesbummage
# cartridgesbummage
# heaterinert
# spiritedjump
# rigelpaunchy
# musicalchampagne
# sociablelemma
# behaviourverbena
# wisefumbling
# unguardedgiant
# guavaconfide
# impetuousfurbelows
# expecteffective
# dotwazzack
# translatecyclist
# ledgeindeed
# replacedbevy
# planktonuses
# meatsoffbeat
# opticsdiameter
# globeshameful
# ellipticalfabricator
# stunassured
# fizzlehelp
# langeredsubset
# chiselleddessicants
# colonclipper
# decanterbalance
# strungebay
# bunchmeats
# twitequiver
# gruntdrive
# sortinterior
# cartridgesbummage
# fattyoddball
# figsql
# axlevirtue
# turnoverlovesick
# rappelarias
# instantthwack
# meatsoffbeat
# behaveterminal
# pleasinghoop
# raggedshrink
# souffleutility
# strungebay
# alloweruptions
# moderatohorn
# carrionscream
# pipetsrockers
# realtorcaustic
# blythpulse
# realtorcaustic
# privacyhaunt
# emeraldclippers
# fixnumquicklime
# sectionssqueaky
# earmarinated
# lickerbond
# fixnumquicklime
# badgefields
# nursingrash
# pancakesgrebe
# nursingrash
# ellipticalfabricator
# amuckpoints
# craytugofwar
# applyingbaker
# geologybeeping
# snaildossier
# hoovessquares
# eminentallergy
# eontop
# heaterinert
# rubbishbladder
# actuallyfoot
# rappelarias
# musicalchampagne
# pleasinghoop
# chichazard
# strungebay
# phobosstaccato
# sectionssqueaky
# axlevirtue
# unicyclistamiable
# sortinterior
# risottospell
# troubledseptum
# troubledseptum
# organicmajor
# cobolglaucous
# troubledseptum
# snaildossier
# unbalancedprotoplanet
# badgefields
# backedammeter
# clucklinnet

# %% [markdown]
# That's a lot of output. Let's combine the `cut` command with the `head` command by *piping* the output of one command into another command.  The vertical bar `|` is the *pipe*.

# %%
# !cut -f1 -d',' data/users.csv | head
# Out:
# user
# parallelconcerned
# driftmvc
# snowdonevasive
# cobolglaucous
# stylishmugs
# hypergalaxyfibula
# pipetsrockers
# bracesworkable
# spiritedjump

# %% [markdown]
# We can use pipes (`|`) to string together many commands to create very powerful one-liners. For example, let's figure out the number of _unique_ users in the first column of the data file. We will get all the values from the first column, sort them, reduce that to only the unique values, and then count the number of lines in the result:

# %%
# !cut -f1 -d',' data/users.csv | sort | uniq | wc -l
# Out:
#      201

# %% [markdown]
# Or, we can get a list of the top-10 most frequently occuring users. If we give `uniq` the `-c` flag, it will return the number of times each value occurs. Since these counts are the first entry in each new line, we can tell `sort` to expect numbers (`-n`) and to give us the results in reverse (`-r`) order. Note, that when you want to use two or more single letter flags, you can just place them one after another.

# %%
# !cut -f1 -d',' data/users.csv | sort | uniq -c | sort -nr | head
# Out:
#   59 compareas
#   56 upbeatodd
#   56 burntrifle
#   56 binomialapathetic
#   54 frequencywould
#   54 ellipticalfabricator
#   53 globeshameful
#   52 badgefields
#   52 ashamedmuscles
#   51 alloweruptions

# %% [markdown]
# After some exploration we decide we want to keep only part of our data and bring it into a new file. Let's find all the records that have a negative value in the second and third columns and put these results in a file called `data/negative_users.csv`. Searching through files can be done using _[regular expressions](http://www.robelle.com/smugbook/regexpr.html#expression)_ with a tool called `grep` (Global Regular Expression Printer).
#
# And remember that we can send the output of a command to the screen or into another command?  You can also direct output of a command (or a string of commands) into a file using the "redirection" operator `>`.  (NB: the pipe is also a redirection operator.  Another redirection operator is `>>`, which concatenates the output to the end of the file, rather than overwriting it.)

# %%
# !grep '.*,-.*,-.*' data/users.csv > data/negative_users.csv

# %%
# !ls data
# Out:
# ds_survey.csv      negative_users.csv users.csv

# %% [markdown]
# ## Packages and built-in functions

# %% [markdown]
# Python has a ton of packages that make doing complicated stuff very easy. We won't discuss how to install packages, or give a detailed list of what packages exist, but we will give a brief description about how they are used.
#
# An easy way to think of why package are useful is by thinking: "**Python packages give us access to MANY functions**".
#
# Packages contain pre-defined functions (built-in) that make our life easier!  We've seen pre-defined functions before, for example, the funciton 'str()' that we used to convert numbers into strings in the Python Basics notebook.
#
# In this class we will use four packages very frequently: `pandas`, `sklearn`, `matplotlib`, and `numpy`:
#
# - **`pandas`** is a data manipulation package. It lets us store data in data frames. More on this soon.
# - **`sklearn`** is a machine learning and data science package. It lets us do fairly complicated machine learning tasks, such as running regressions and building classification models with only a few lines of code. (Nice!)
# - **`matplotlib`** lets you make plots and graphs directly from your code.  This can be a secret weapon when combined with notebooks, as you can very easily rerun analyses on different data or with slightly different code, and the graphs can just appear magically.  (Ok, always easier said than done, but you get the idea.)
# - **`numpy`** (pronounced num-pie) is used for doing "math stuff", such as complex mathematical operations (e.g., square roots, exponents, logs), operations on matrices, and more.
#
# As we use these through the semester, their usefulness will become increasingly apparent.

# %% [markdown]
# To make the contents of a package available, you need to import it:

# %%
import pandas
import sklearn
import matplotlib
import numpy

# %% [markdown]
# Sometimes it is easier to use short names for packages. This has become the norm now, so let's do it sometimes so that you recognize it if you encounter it in your work.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# We can now use package-specific things. For example, numpy has a function called `sqrt()` which will give us the square root of a numpy number. Since it is part of numpy, we need to tell Python that that's where it is by using a dot (e.g., `np.sqrt()`).
#
# In the following cell you can also see how to write **comments** in your code. Take my advice: write comments as you go.  It's helpful when you want to collaborate, then you don't have to figure out what you did to explain it to your collaborator.  But even more: often you need to come back to an analysis weeks, months, or even years later, and you will thank yourself for explaining what you did!

# %%
some_list = [0,0,1,2,3,3,4.5,7.6]
some_dictionary = {'student1': '(929)-000-0000', 'student2': '(917)-000-0000', 'student3': '(470)-000-0000'}
some_set = set( [1,2,4,4,5,5] )


# In this part of the code I am using numpy (np) functions

print ("Square root: " + str ( np.sqrt(25) ))
print ("Maximum element of our previous list: " + str( np.max(some_list) ))

# In this part of the code I am using python functions

print ("Number of elements in our previous list: " + str( len(some_list) ))
print ("Sum of elements in our previous list: " + str( sum(some_list) ))
print ("Range of 5 numbers (remember we start with 0): " + str( range(5) ))
# Out:
# Square root: 5.0
# Maximum element of our previous list: 7.6
# Number of elements in our previous list: 8
# Sum of elements in our previous list: 21.1
# Range of 5 numbers (remember we start with 0): [0, 1, 2, 3, 4]

# %% [markdown]
# What about the package **Pandas**?
#
# Pandas gives us the **DATAFRAME** -- one of the main data structures used in data analytics.
#
# A Dataframe is 2-dimensional "labeled" data structure with columns of potentially different types. It is generally the most commonly used pandas object. Along with the data, you can optionally pass index (row labels) and columns (column labels) arguments. [More details here](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe)
#
# Let's build a dataframe called `data_pandas`, starting by creating some data records (the lists), and then putting them into a dataframe, with the columns labeled:

# %%
list1 = ['studentA',22,'(929)-000-000']
list2 = ['studentB',np.nan,'(646)-000-000']
list3 = ['studentC',30,'(917)-000-000']
list4 = ['studentD',31,'(646)-001-001']
list5 = ['studentE',np.nan,'(929)-001-001']
list6 = ['studentF',30,'(917)-001-001']
list7 = ['studentG',30,'(470)-001-001']

data_pandas = pd.DataFrame([list1,list2,list3,list4,list5,list6,list7],columns=['Name','Age','Mobile'])
data_pandas
# Out:
#        Name   Age         Mobile
# 0  studentA  22.0  (929)-000-000
# 1  studentB   NaN  (646)-000-000
# 2  studentC  30.0  (917)-000-000
# 3  studentD  31.0  (646)-001-001
# 4  studentE   NaN  (929)-001-001
# 5  studentF  30.0  (917)-001-001
# 6  studentG  30.0  (470)-001-001

# %% [markdown]
# Now: Count the number of rows with different Ages:

# %%
data_pandas.groupby('Age').count()
# Out:
#       Name  Mobile
# Age
# 22.0     1       1
# 30.0     3       3
# 31.0     1       1

# %% [markdown]
# We can select a subset of the columns by passing a list with the corresponding column names:

# %%
data_pandas[ ['Name','Age'] ]
# Out:
#        Name   Age
# 0  studentA  22.0
# 1  studentB   NaN
# 2  studentC  30.0
# 3  studentD  31.0
# 4  studentE   NaN
# 5  studentF  30.0
# 6  studentG  30.0

# %% [markdown]
# We can also add columns ( they should have the same number of rows as the dataframe they are being added to! )

# %%
data_pandas['business_major'] = ['yes','no','yes','yes','yes','no','yes']
data_pandas['years_experience'] = [1,4,2,6,0,3,0]

data_pandas
# Out:
#        Name   Age         Mobile business_major  years_experience
# 0  studentA  22.0  (929)-000-000            yes                 1
# 1  studentB   NaN  (646)-000-000             no                 4
# 2  studentC  30.0  (917)-000-000            yes                 2
# 3  studentD  31.0  (646)-001-001            yes                 6
# 4  studentE   NaN  (929)-001-001            yes                 0
# 5  studentF  30.0  (917)-001-001             no                 3
# 6  studentG  30.0  (470)-001-001            yes                 0

# %% [markdown]
# What if we take a look again? But now let's use "sum" to see all values, not just counts ( sum / aggregate )

# %%
data_pandas.groupby('Age').sum()
# Out:
#       years_experience
# Age
# 22.0                 1
# 30.0                 5
# 31.0                 6

# %% [markdown]
# ****
#
# What is the average age? (Combine packages: numpy and pandas)

# %%
np.mean( data_pandas['Age'] )
# Out:
# 28.6

# %% [markdown]
# What about operations on entire columns? This can make data munging much easier!
#
# Let's take the difference between age and years of experience:
#
# _(Look how I select columns here!)_

# %%
data_pandas.Age - data_pandas.years_experience
# Out:
# 0    21.0
# 1     NaN
# 2    28.0
# 3    25.0
# 4     NaN
# 5    27.0
# 6    30.0
# dtype: float64

# %% [markdown]
# ### Reading files and more plotting
#
# There are many ways to read data in Python. We will discuss two
# options:
#
# (1) reading line by line (streaming)
#
# (2) using Pandas to read data into dataframes (Homework 1)
#
# Reading in data **line by line** can be less structured since it depends on you knowing or determining
# what each line looks like. For structured data, this might be an unnecessary waste of time. However, for
# highly unstructed data, this can be very useful.

# %%
# Read in the data/users.csv file line by line
file = open("data/users.csv", "r")
line_user = []
line_var1 = []
line_var2 = []
for line in file:
    # Break up the line, presuming comma-separated data
    user, variable1, variable2 = line.split(",")
    # Skip the header row
    if user == "user":
        continue
    line_user.append(user)
    line_var1.append(variable1)
    line_var2.append(variable2)
    # Print the user and the sum of variable1 and variable2
    print("%s: %.3f" % (user, float(variable1) + float(variable2)))
# Out:
# parallelconcerned: 139.310
# driftmvc: 140.582
# snowdonevasive: 138.469
# cobolglaucous: 140.156
# stylishmugs: 137.777
# hypergalaxyfibula: 140.085
# pipetsrockers: 15.735
# bracesworkable: 12.513
# spiritedjump: 16.328
# barnevidence: 7.828
# emeraldclippers: 47.587
# maintainwiggly: 50.882
# submittedwavelength: 49.068
# clucklinnet: 48.526
# bluetailgodwottery: 42.923
# microwavejar: 41.379
# croutonwrack: 41.591
# submittedwavelength: 42.189
# moderatohorn: 47.217
# heaterinert: 43.145
# micaassistant: -38.024
# gaudyfea: -46.976
# turnoverlovesick: -18.860
# amuckpoints: -4.691
# allegatorwafers: -76.690
# expecteffective: -21.274
# mincegaiters: -19.072
# peacefulceaseless: -22.666
# decanterbalance: -31.779
# synonympatisserie: -75.320
# starbucksbluetail: -50.042
# pipeathlete: -36.030
# radicandoceanic: -74.818
# somethingalbedo: -68.336
# craytugofwar: -18.441
# pipetsrockers: -18.339
# unbalancedprotoplanet: -47.327
# emeraldclippers: -59.370
# ischemicfrosted: -72.786
# binomialapathetic: 1.969
# stairsgobsmacked: -19.166
# ledgeindeed: -75.085
# badgefields: -77.669
# synonympatisserie: -71.043
# worldlyventuri: -8.181
# globeshameful: -71.610
# alloweruptions: -48.952
# burritoscarriage: -64.441
# grabbig: -60.270
# dronessomersault: -32.977
# latticelaboratory: -53.756
# ellipticalfabricator: -62.886
# amuckpoints: -5.819
# guavaconfide: -65.179
# fundingticket: -4.799
# croutonwrack: -20.668
# elatedunicorn: -20.351
# freelysociable: -47.004
# loindecorate: -52.509
# micaassistant: -59.476
# dweebspices: -32.372
# latticelaboratory: -24.079
# babyambitious: -15.703
# specifiedinnovative: -37.161
# colonclipper: -14.353
# pipeathlete: -49.495
# cranesurgeon: -42.913
# belchedsodding: -47.043
# actuallyfoot: -27.214
# horsesmultiply: -36.761
# microwavejar: -27.899
# snaildossier: -54.943
# globeshameful: -18.628
# eontop: -42.865
# tendonwench: -5.283
# flakyunlawful: -27.987
# twitequiver: -10.006
# showerspain: -69.742
# figsql: -36.918
# barnevidence: -12.000
# shrillbanjos: -57.663
# maintainwiggly: -35.508
# fundingticket: -35.527
# planktonuses: -54.398
# elatedunicorn: -56.763
# agenascientists: 20.237
# barnevidence: -69.422
# swankythough: -72.252
# paddlevacuole: -55.229
# stairsgobsmacked: -54.569
# flickcanapes: -29.317
# unicyclistamiable: -29.718
# hypergalaxyfibula: -28.323
# mtvgrosbeak: -11.599
# wordsundress: -30.042
# ledgeindeed: -28.041
# moderatohorn: -72.269
# alloweruptions: -55.874
# surmiseteenagers: -58.543
# somethingalbedo: -30.347
# somethingalbedo: -52.459
# hoursethanoate: -61.220
# looroasting: -48.371
# lymphomamellow: -73.494
# stylishmugs: -38.768
# dampedbrioche: -14.452
# craytugofwar: -34.133
# unguardedgiant: -76.159
# wordsundress: -52.350
# unbalancedprotoplanet: -34.329
# epsiloncloning: -24.602
# ytterbiumprovincial: -61.712
# disjointtoday: -40.680
# gogglesknacker: -68.706
# croutonwrack: -44.575
# bashrower: -63.169
# bunchmeats: -18.566
# binomialapathetic: -75.176
# behaveterminal: -54.234
# wonderfulscullian: -40.952
# sortinterior: -63.705
# loindecorate: -51.197
# paddlevacuole: -55.474
# hoovessquares: -5.631
# hoovessquares: -13.886
# musicalchampagne: -69.484
# eontop: -20.252
# guavaconfide: -21.820
# chiselleddessicants: -23.746
# popmatrices: -62.474
# poundingfrustum: -29.304
# easybobolink: -34.174
# wisefumbling: -26.253
# compareas: -20.574
# clucklinnet: -51.942
# meggingswine: -11.631
# sectionssqueaky: -17.393
# crepegrape: -53.249
# crepegrape: -12.297
# neckedjre: -42.063
# micaassistant: -33.409
# twitequiver: -32.807
# bluetailgodwottery: -35.769
# xslhopeful: -63.593
# farrowcetti: -28.270
# craytugofwar: -19.703
# peacefulceaseless: -12.468
# cranniescigarette: -30.629
# singesculptor: -50.111
# specifiedinnovative: -57.468
# emeraldclippers: 3.514
# tendonwench: -29.729
# dampedbrioche: -10.331
# snowdonevasive: -61.517
# colonclipper: -73.991
# bracesworkable: -52.576
# duexslt: -36.361
# simplicityfairy: -31.367
# hoursethanoate: -47.330
# flakyunlawful: -13.943
# tendonwench: -69.871
# showerspain: -60.227
# showerspain: -66.170
# lasttaiga: -59.948
# canalhateful: -54.529
# rappelarias: -60.702
# hypergalaxyfibula: -64.502
# historypant: -41.791
# rubbishbladder: 0.431
# elatedunicorn: -32.154
# cranniescigarette: -68.789
# cranesurgeon: -74.108
# disjointtoday: -38.118
# agenascientists: -73.335
# handywrist: -74.358
# ledgeindeed: -33.059
# gammagot: -62.906
# blythpulse: -72.358
# blythpulse: -63.761
# impetuousfurbelows: -70.139
# guavaconfide: -16.831
# gravelscientific: -24.030
# strungebay: -74.779
# analbar: -44.212
# xslhopeful: -57.399
# wisefumbling: -35.326
# compareas: -7.107
# gnarledbaggy: -5.133
# mincegaiters: -33.054
# sociablelemma: -38.619
# gnarledbaggy: -19.599
# gogglesknacker: -35.953
# snowdonevasive: -35.723
# cleaningburnt: -36.683
# hoovessquares: -51.978
# binomialapathetic: -59.484
# flinkjordan: -78.559
# tyrespan: -39.309
# moderatohorn: -76.686
# allegatorwafers: -61.643
# europiumcentury: -16.042
# bluetailgodwottery: -72.570
# quadratcranky: -19.932
# simplicityfairy: -71.168
# wordsundress: -67.453
# feverspolystyrene: 39.318
# batchquickest: 39.539
# alloweruptions: 41.782
# alloweruptions: 39.906
# mtvgrosbeak: 33.745
# snowdonevasive: 39.422
# compareas: 26.996
# fattyoddball: 35.346
# sectionssqueaky: 38.404
# fattyoddball: 28.263
# fattyoddball: 42.669
# guavaconfide: 33.294
# maintainwiggly: 36.379
# tyrespan: 44.631
# behaviourverbena: 42.896
# meggingswine: 43.552
# elatedunicorn: 36.242
# ytterbiumprovincial: 36.804
# clucklinnet: 34.930
# tweezerscurve: 19.533
# gaudyfea: 37.544
# freelysociable: 35.010
# canalhateful: 33.567
# tubingwheatear: 35.003
# surmiseteenagers: 34.578
# fattyoddball: 35.355
# deficientclunking: 27.651
# spiritedjump: 40.532
# fattyoddball: 33.431
# belchedsodding: 36.178
# gammagot: 37.813
# neighborlyrook: 29.763
# completionskylark: 39.156
# babyambitious: 36.693
# deficientclunking: 29.513
# trapdoormongrel: 37.330
# singesculptor: 37.694
# rigelpaunchy: 8.742
# canalhateful: 10.841
# completionskylark: 6.829
# dweebspices: 5.438
# trapdoormongrel: 8.694
# microwavejar: 7.575
# mincegaiters: 5.033
# trapdoormongrel: 3.121
# gogglesknacker: 1.335
# backedammeter: 2.665
# epsiloncloning: 0.320
# copalinstruct: 3.831
# amuckpoints: -0.315
# trapdoormongrel: -1.914
# risottospell: 1.538
# dialgraft: 16.270
# axlevirtue: 12.548
# cleaningburnt: 11.916
# listenerabandoned: 13.323
# pipeathlete: 14.036
# gogglesknacker: 18.868
# hoovessquares: 11.341
# replacedbevy: 12.934
# snowdonevasive: 18.509
# ashamedmuscles: 18.016
# musicalchampagne: 20.572
# cowardlyabout: 24.936
# hoovessquares: 16.318
# stairsgobsmacked: 9.899
# eminentallergy: 16.114
# eontop: 11.965
# twitequiver: 18.124
# binomialapathetic: 21.688
# horsesmultiply: 18.816
# simplicityfairy: 20.629
# peacefulceaseless: 15.665
# singesculptor: 20.141
# bunchmeats: 24.966
# meggingswine: 31.837
# heomicron: 26.000
# farrowcetti: 22.763
# fizzlehelp: 46.513
# bonelliseal: 47.078
# ashamedmuscles: 47.037
# deficientclunking: 42.688
# neighborlyrook: 43.245
# turnoverlovesick: 43.980
# popmatrices: 46.664
# stairsgobsmacked: 44.650
# ellipticalfabricator: 40.959
# gnarledbaggy: 45.409
# sectionssqueaky: 42.050
# gilletteclammy: 10.859
# analbar: 7.420
# raggedshrink: 55.650
# grabbig: 55.527
# unbalancedprotoplanet: 56.638
# singesculptor: 55.386
# bismuthcolloquial: 55.116
# worldlyventuri: 54.913
# guavaconfide: 54.407
# chiselleddessicants: 53.743
# trapdoormongrel: 54.889
# ceilinjuries: 54.022
# rappelarias: 56.081
# gnarledbaggy: 54.061
# sectionssqueaky: 56.538
# europiumcentury: 55.994
# gammagot: 55.440
# dotwazzack: 54.618
# radicandoceanic: 56.355
# fixnumquicklime: 56.018
# opticsdiameter: 65.713
# nursingrash: 63.488
# fixnumquicklime: 64.016
# synonympatisserie: 66.783
# applyingbaker: -47.180
# chiselleddessicants: 64.863
# freelysociable: 63.304
# ashamedmuscles: 63.605
# bashrower: 64.650
# handywrist: 66.060
# emeraldclippers: 66.496
# europiumcentury: 65.362
# fizzclimbing: 67.037
# rappelarias: 62.630
# hoovessquares: 65.344
# tyrespan: 63.700
# swankythough: 66.313
# axlevirtue: 67.502
# looroasting: 66.421
# upbeatodd: 65.425
# gilletteclammy: 65.903
# ellipticalfabricator: 64.900
# lasttaiga: 61.938
# musicalchampagne: 58.570
# buoyancycowardice: 59.819
# fixnumquicklime: 63.619
# hoovessquares: 65.877
# handywrist: 58.009
# rappelarias: 58.056
# producecoven: 60.140
# colonclipper: 60.566
# cheapersyllable: 63.674
# unbalancedprotoplanet: 56.324
# unicyclistamiable: 57.912
# clucklinnet: 65.847
# simplicityfairy: 62.146
# applyingbaker: 61.834
# synonympatisserie: 58.602
# casesslippery: 57.213
# pancakesgrebe: 57.987
# driftmvc: 59.716
# blythpulse: 57.975
# unguardedgiant: 58.117
# bashrower: 61.466
# opticsdiameter: 58.791
# unbalancedprotoplanet: 63.373
# bismuthcolloquial: 64.525
# unicyclistamiable: 64.525
# ischemicfrosted: 56.934
# feverspolystyrene: 58.701
# copalinstruct: 59.383
# ellipticalfabricator: 58.340
# axlevirtue: 60.510
# swankythough: 57.735
# sectionssqueaky: 60.230
# moderatohorn: 58.837
# synonympatisserie: 59.131
# bracesworkable: 59.357
# cranesurgeon: 57.874
# stylishmugs: 61.120
# translatecyclist: 58.633
# gruntdrive: 59.364
# wisefumbling: 61.419
# troubledseptum: 61.831
# bismuthcolloquial: 57.874
# hoovessquares: 57.183
# flakyunlawful: 65.210
# apronextension: 64.446
# neighborlyrook: 59.043
# advisorlanguage: 61.623
# dotwazzack: 60.927
# organicmajor: 62.144
# craytugofwar: 60.547
# chichazard: 57.854
# gammagot: 56.652
# badgefields: 57.754
# sociablelemma: 56.610
# disjointtoday: 56.496
# quadratcranky: 55.855
# singesculptor: 57.427
# xslhopeful: 58.902
# eontop: 65.346
# cobolglaucous: 62.875
# guavaconfide: 60.786
# ischemicfrosted: 62.126
# guavaconfide: 62.080
# buoyancycowardice: 60.619
# shrillbanjos: 60.714
# ledgeindeed: 61.558
# advisorlanguage: 60.305
# handywrist: 60.937
# allocatesposts: 64.150
# barnevidence: 63.822
# actuallyfoot: 63.254
# ischemicfrosted: 83.469
# tubingwheatear: 81.821
# europiumcentury: 80.739
# somethingalbedo: 82.892
# easybobolink: 84.246
# turnoverlovesick: 84.998
# advisorlanguage: 91.787
# stylishmugs: 83.318
# flickcanapes: 86.643
# stunassured: 85.297
# freelysociable: 85.281
# surmiseteenagers: 84.763
# pancakesgrebe: 82.932
# rigelpaunchy: 85.536
# sociablelemma: 84.115
# ytterbiumprovincial: 90.153
# sortinterior: 92.240
# producecoven: 96.013
# deficientclunking: 92.270
# looroasting: 88.078
# simplicityfairy: 86.179
# worldlyventuri: 90.381
# figsql: 91.978
# poundingfrustum: 84.856
# freelysociable: 86.864
# agenascientists: 93.870
# organicmajor: 95.227
# hoovessquares: 92.548
# smackswallow: 90.805
# musicalchampagne: 86.838
# paddlevacuole: 89.189
# troubledseptum: 80.020
# meatsoffbeat: 86.466
# upbeatodd: 88.888
# realtorcaustic: 84.630
# cartridgesbummage: 90.285
# wisefumbling: 83.439
# meggingswine: 83.262
# sectionssqueaky: 92.349
# ceilinjuries: 89.658
# latticelaboratory: 89.384
# grabbig: 90.422
# figsql: 92.395
# upbeatodd: 84.853
# buoyancycowardice: 90.888
# hoursethanoate: 87.861
# neckedjre: 94.014
# mtvgrosbeak: 85.019
# parallelconcerned: 85.800
# latticelaboratory: 82.777
# eontop: 87.835
# poundingfrustum: 84.813
# dampedbrioche: 90.040
# looroasting: 88.776
# rappelarias: 48.442
# badgefields: 46.747
# clucklinnet: 48.746
# frequencywould: 47.882
# listenerabandoned: 50.706
# carrionscream: 50.890
# rubbishbladder: 51.576
# unguardedgiant: 49.727
# worldlyventuri: 50.258
# meatsoffbeat: 49.611
# smackswallow: 50.945
# poundingfrustum: 50.578
# canalhateful: 51.079
# craytugofwar: 51.189
# binomialapathetic: 46.937
# eontop: 45.445
# lasttaiga: 49.512
# metaiota: 49.405
# apronextension: 44.830
# bonelliseal: 47.969
# risottospell: 48.371
# dialgraft: 46.872
# strungebay: 48.053
# upbeatodd: 47.538
# metaiota: 48.664
# wordsundress: 50.484
# moderatohorn: 51.506
# rappelarias: 46.317
# historypant: 48.938
# historypant: 49.593
# organicmajor: 50.154
# alloweruptions: 47.491
# applyingbaker: 46.833
# frequencywould: 47.012
# raggedshrink: 50.538
# somethingalbedo: 51.363
# applyingbaker: 50.958
# chiselleddessicants: 51.561
# behaviourverbena: 50.499
# decanterbalance: 50.595
# heaterinert: 50.476
# troubledseptum: 51.016
# burntrifle: 52.267
# blythpulse: 51.895
# heaterinert: 52.688
# dotwazzack: 53.153
# lymphomamellow: 52.128
# crepegrape: 52.329
# replacedbevy: 50.743
# realtorcaustic: 53.224
# sectionssqueaky: 50.867
# langeredsubset: 52.205
# feverspolystyrene: 50.862
# europiumcentury: 50.200
# backedammeter: 49.459
# axlevirtue: 53.346
# quadratcranky: 53.080
# expecteffective: 51.503
# mtvgrosbeak: 48.688
# latticelaboratory: 50.338
# advisorlanguage: 50.130
# poohvireo: 50.526
# wonderfulscullian: 56.053
# craytugofwar: 58.583
# flakyunlawful: 55.366
# emeraldclippers: 55.004
# tubingwheatear: 53.495
# compareas: 51.439
# risottospell: 52.578
# troubledseptum: 49.425
# translatecyclist: 50.923
# moderatohorn: 50.118
# handywrist: 59.137
# sociablelemma: 53.427
# loindecorate: 51.884
# producecoven: 49.630
# organicmajor: 53.504
# eontop: 54.366
# batchquickest: 52.380
# eontop: 52.217
# batchquickest: 53.959
# tweezerscurve: 52.120
# globeshameful: 51.876
# moderatohorn: 52.006
# cranniescigarette: 51.456
# meatsoffbeat: 47.321
# ceilinjuries: 48.929
# trapdoormongrel: 50.517
# ledgeindeed: 50.521
# microwavejar: 52.970
# singesculptor: 52.848
# looroasting: 53.084
# metaiota: 52.249
# fizzlehelp: 49.892
# replacedbevy: 50.166
# gnarledbaggy: 50.291
# allegatorwafers: 50.334
# dweebspices: 51.135
# hoovessquares: 52.927
# flickcanapes: 52.717
# simplicityfairy: 52.757
# allocatesposts: 52.639
# chichazard: 53.116
# binomialapathetic: 52.087
# stylishmugs: 52.757
# dampedbrioche: 52.136
# troubledseptum: 52.796
# rubbishbladder: 52.642
# flinkjordan: 52.823
# mincegaiters: 52.547
# impetuousfurbelows: 52.401
# historypant: 53.199
# dialgraft: -110.270
# opticsdiameter: 57.073
# pipeathlete: 56.857
# globeshameful: 56.682
# cartridgesbummage: 57.934
# smackswallow: 59.249
# bashrower: 56.825
# upbeatodd: 59.699
# fizzlehelp: 56.499
# sociablelemma: 57.704
# cobolglaucous: 57.988
# meatsoffbeat: 58.989
# tyrespan: 56.394
# expecteffective: 57.403
# lasttaiga: 59.144
# handywrist: 56.584
# raggedshrink: 55.791
# fizzlehelp: 43.350
# compareas: 44.359
# meatsoffbeat: 47.151
# upbeatodd: 45.092
# replacedbevy: 42.657
# gravelscientific: 46.850
# chichazard: 43.777
# barnevidence: 45.681
# neckedjre: 45.100
# privacyhaunt: 66.919
# popmatrices: 64.892
# troubledseptum: 68.274
# mtvgrosbeak: 64.079
# crepegrape: 68.324
# decanterbalance: 65.422
# risottospell: 68.277
# eontop: 66.139
# strungebay: 65.808
# unbalancedprotoplanet: 64.149
# raggedshrink: 67.717
# burritoscarriage: 69.823
# showerspain: 64.756
# dampedbrioche: 64.489
# bracesworkable: 65.723
# ashamedmuscles: 65.774
# parallelconcerned: 64.767
# heomicron: 54.786
# gaudyfea: 66.306
# producecoven: 64.344
# replacedbevy: 66.942
# allegatorwafers: 55.838
# planktonuses: 68.671
# swankythough: 85.437
# horsesmultiply: 93.348
# phobosstaccato: 67.140
# gilletteclammy: 77.679
# dampedbrioche: 81.634
# pipeathlete: 65.512
# babyambitious: 100.293
# ceilinjuries: 66.290
# mincegaiters: 68.929
# binomialapathetic: 87.596
# sociablelemma: 85.169
# upbeatodd: 70.304
# colonclipper: 66.608
# unbalancedprotoplanet: 71.294
# amuckpoints: 64.554
# moderatohorn: 92.626
# planktonuses: 70.936
# mtvgrosbeak: 71.005
# musicalchampagne: 99.617
# impetuousfurbelows: 64.726
# cuboidpass: 70.007
# gilletteclammy: 78.999
# burntrifle: 95.042
# gruntdrive: 68.778
# badgefields: 73.303
# realtorcaustic: 73.921
# realtorcaustic: 70.164
# dotwazzack: 93.712
# bunchmeats: 68.752
# smackswallow: 65.133
# advisorlanguage: 78.426
# flinkjordan: 88.602
# fixnumquicklime: 69.445
# coatprecious: 74.382
# colonclipper: 64.515
# fizzlehelp: 73.180
# chichazard: 72.844
# allocatesposts: 69.863
# earmarinated: 69.272
# guavaconfide: 69.554
# badgefields: 71.784
# barnevidence: 69.247
# compareas: 72.129
# fixnumquicklime: 68.487
# simplicityfairy: 71.586
# phobosstaccato: 69.617
# feverspolystyrene: 73.133
# europiumcentury: 67.989
# risottospell: 67.937
# babyambitious: 73.928
# duexslt: 74.714
# lasttaiga: 77.486
# alloweruptions: 71.532
# popmatrices: 71.551
# tendonwench: 69.943
# hypergalaxyfibula: 71.826
# ledgeindeed: 71.758
# burntrifle: 71.640
# peacefulceaseless: 69.645
# binomialapathetic: 72.429
# geologybeeping: 70.663
# organicmajor: 73.021
# peacefulceaseless: 71.141
# deficientclunking: 77.309
# paddlevacuole: 73.842
# handywrist: 75.469
# xslhopeful: 75.701
# fizzlehelp: 72.315
# eminentallergy: 72.216
# bunchmeats: 70.872
# ashamedmuscles: 70.007
# simplicityfairy: 68.814
# singesculptor: 73.848
# earmarinated: 70.864
# meatsoffbeat: 72.973
# pipetsrockers: 68.902
# applyingbaker: 69.511
# gnarledbaggy: 71.429
# heaterinert: 71.657
# emeraldclippers: 79.197
# gaudyfea: 76.156
# farrowcetti: 76.471
# gammagot: 87.947
# allocatesposts: 78.849
# rubbishbladder: 86.643
# gogglesknacker: 80.817
# axlevirtue: 83.265
# flinkjordan: 77.931
# bismuthcolloquial: 79.972
# wisefumbling: 82.398
# ceilinjuries: 86.659
# worldlyventuri: 88.159
# ashamedmuscles: 75.903
# cranesurgeon: 85.702
# bluetailgodwottery: 79.484
# unbalancedprotoplanet: 84.075
# pipeathlete: 81.413
# mincegaiters: 84.872
# rigelpaunchy: 74.262
# synonympatisserie: 76.223
# analbar: 87.666
# tubingwheatear: 86.025
# actuallyfoot: 75.311
# meggingswine: 77.571
# sociablelemma: 77.296
# cobolglaucous: 75.937
# ashamedmuscles: 73.349
# dweebspices: 77.545
# poundingfrustum: 74.087
# batchquickest: 74.837
# peacefulceaseless: 76.059
# dronessomersault: 76.009
# swankythough: 88.022
# tendonwench: 56.665
# dialgraft: 57.037
# fattyoddball: 60.835
# batchquickest: 59.615
# coatprecious: 61.361
# apronextension: 62.613
# mincegaiters: 59.678
# radicandoceanic: 60.400
# flickcanapes: 58.130
# burntrifle: 57.681
# disjointtoday: 59.350
# troubledseptum: 60.318
# tyrespan: 63.117
# tendonwench: 61.639
# hypergalaxyfibula: 59.131
# metaiota: 61.054
# smackswallow: 59.944
# stairsgobsmacked: 62.426
# twitequiver: 60.927
# neighborlyrook: 57.003
# burntrifle: 63.850
# feverspolystyrene: 61.422
# micaassistant: 66.197
# cobolglaucous: 57.489
# ledgeindeed: 63.976
# impetuousfurbelows: 61.215
# belchedsodding: 66.908
# radicandoceanic: 61.885
# bunchmeats: 61.401
# replacedbevy: 58.027
# freelysociable: 58.375
# bunchmeats: 58.977
# surmiseteenagers: 57.237
# latticelaboratory: 60.271
# gammagot: 59.473
# poohvireo: 64.936
# popmatrices: 60.250
# rappelarias: 59.047
# turnoverlovesick: 59.922
# langeredsubset: 60.229
# wonderfulscullian: -12.042
# snaildossier: -10.468
# craytugofwar: 2.063
# ashamedmuscles: -5.618
# eminentallergy: -2.790
# fattyoddball: 0.088
# translatecyclist: -0.738
# lasttaiga: -15.363
# europiumcentury: -11.774
# handywrist: 0.980
# mtvgrosbeak: -5.210
# easybobolink: 3.484
# gogglesknacker: -0.914
# realtorcaustic: 2.154
# neckedjre: -11.627
# lickerbond: -7.652
# bluetailgodwottery: -6.787
# lickerbond: 1.465
# barnevidence: -1.218
# wordsundress: 0.871
# blythpulse: 6.680
# musicalchampagne: -5.034
# xslhopeful: 2.107
# smackswallow: -0.153
# expecteffective: -4.038
# driftmvc: 1.645
# submittedwavelength: -0.345
# dialgraft: -4.045
# alloweruptions: -12.594
# loindecorate: 1.988
# farrowcetti: 0.009
# burritoscarriage: 6.537
# completionskylark: -14.809
# mtvgrosbeak: 1.168
# copalinstruct: 3.755
# fattyoddball: -0.514
# peacefulceaseless: 4.294
# copalinstruct: 2.699
# pleasinghoop: 19.284
# disjointtoday: 6.092
# compareas: 1.205
# frequencywould: 4.418
# gilletteclammy: 2.206
# historypant: 3.749
# tubingwheatear: -14.304
# smackswallow: -11.418
# upbeatodd: -8.368
# gogglesknacker: -10.763
# singesculptor: 7.218
# popmatrices: 5.558
# rigelpaunchy: -2.086
# wordsundress: 0.750
# croutonwrack: 1.840
# trapdoormongrel: 5.613
# smackswallow: 0.411
# ceilinjuries: 0.614
# translatecyclist: -5.038
# globeshameful: 3.351
# sortinterior: 1.627
# binomialapathetic: -13.909
# upbeatodd: -11.750
# dweebspices: 2.646
# replacedbevy: -14.995
# latticelaboratory: 2.149
# easybobolink: 2.355
# tyrespan: -4.649
# lickerbond: -13.574
# radicandoceanic: 6.628
# snaildossier: -5.267
# cuboidpass: -2.875
# gravelscientific: 2.562
# spiritedjump: 6.505
# micaassistant: 3.096
# stunassured: -7.139
# spiritedjump: -2.874
# completionskylark: -2.254
# dialgraft: 1.288
# eminentallergy: -13.096
# lickerbond: 1.394
# barnevidence: 2.570
# snowdonevasive: 3.360
# parallelconcerned: 2.393
# copalinstruct: -1.328
# specifiedinnovative: -15.402
# peacefulceaseless: 0.443
# ashamedmuscles: 6.315
# burritoscarriage: 0.089
# dotwazzack: 7.330
# driftmvc: 3.459
# loindecorate: 1.363
# specifiedinnovative: 5.770
# poundingfrustum: 11.001
# pipeathlete: 15.419
# privacyhaunt: 17.654
# guavaconfide: 7.071
# axlevirtue: 4.778
# namibianstabbing: 22.917
# amuckpoints: 20.008
# wonderfulscullian: 11.711
# cobolglaucous: 12.464
# quadratcranky: -22.363
# poohvireo: 37.253
# gruntdrive: 43.603
# burntrifle: 65.098
# listenerabandoned: 13.450
# cartridgesbummage: 13.726
# bunchmeats: 24.709
# burntrifle: 16.388
# crepegrape: 20.916
# phobosstaccato: 22.706
# instantthwack: 15.892
# evaporatingplug: 16.162
# singesculptor: 15.359
# dampedbrioche: 15.321
# specifiedinnovative: 8.001
# feverspolystyrene: 13.122
# upbeatodd: 18.678
# cartridgesbummage: 7.908
# farrowcetti: 15.667
# binomialapathetic: 15.249
# unguardedgiant: 31.738
# stunassured: 31.468
# cheapersyllable: 32.299
# risottospell: 32.476
# privacyhaunt: 34.623
# moderatohorn: 34.104
# decanterbalance: 28.682
# gilletteclammy: 25.888
# alloweruptions: 32.722
# analbar: 31.283
# neckedjre: 24.033
# chiselleddessicants: 36.942
# turnoverlovesick: 33.610
# fundingticket: 34.969
# planktonuses: 35.800
# risottospell: 35.321
# micaassistant: 33.134
# tweezerscurve: 30.685
# raggedshrink: 35.003
# flinkjordan: 27.739
# frequencywould: 34.252
# cleaningburnt: 35.896
# eontop: 36.627
# cheapersyllable: 33.095
# fixnumquicklime: 35.148
# gnarledbaggy: 21.918
# guavaconfide: 25.670
# sociablelemma: 25.015
# dweebspices: 25.902
# hypergalaxyfibula: 27.157
# handywrist: 21.622
# twitequiver: 20.345
# realtorcaustic: 7.977
# bonelliseal: 0.795
# epsiloncloning: 6.591
# axlevirtue: -46.991
# trapdoormongrel: 2.952
# disjointtoday: 4.543
# unguardedgiant: 1.165
# pipetsrockers: 4.373
# amuckpoints: 6.787
# pancakesgrebe: 3.062
# compareas: 7.533
# ledgeindeed: 3.044
# poundingfrustum: 10.743
# fattyoddball: 6.231
# sociablelemma: -1.350
# burntrifle: 8.130
# europiumcentury: 7.425
# snaildossier: -1.790
# gruntdrive: 13.124
# sociablelemma: 13.008
# troubledseptum: 9.541
# babyambitious: 13.569
# worldlyventuri: 8.043
# disjointtoday: 7.688
# bunchmeats: 13.470
# bashrower: 9.871
# tubingwheatear: 11.782
# evaporatingplug: 9.075
# strungebay: 7.090
# rubbishbladder: 15.111
# nursingrash: 11.532
# unicyclistamiable: 21.992
# buoyancycowardice: 25.639
# actuallyfoot: 6.652
# expecteffective: 27.890
# neckedjre: 28.993
# croutonwrack: 24.327
# barnevidence: 26.224
# bracesworkable: 24.176
# elatedunicorn: 27.536
# lymphomamellow: 19.014
# ceilinjuries: 17.170
# behaveterminal: 17.535
# allegatorwafers: 19.648
# wonderfulscullian: 13.295
# namibianstabbing: 45.721
# flinkjordan: 47.959
# chichazard: 41.067
# peacefulceaseless: 50.847
# burntrifle: 51.372
# loindecorate: 49.144
# driftmvc: 34.691
# mtvgrosbeak: 24.696
# specifiedinnovative: 27.168
# colonclipper: 37.028
# hoovessquares: 8.600
# freelysociable: 13.173
# hoovessquares: 10.570
# fizzlehelp: 7.743
# hoursethanoate: 13.161
# historypant: 12.365
# unbalancedprotoplanet: 14.753
# crepegrape: 13.630
# dronessomersault: 10.804
# xslhopeful: 9.799
# agenascientists: 10.426
# planktonuses: 8.391
# cobolglaucous: 19.295
# surmiseteenagers: 23.939
# driftmvc: 20.454
# amuckpoints: 19.992
# grabbig: 22.567
# cowardlyabout: -1.910
# sortinterior: -1.801
# smackswallow: 11.059
# troubledseptum: 11.001
# bashrower: 6.421
# synonympatisserie: 6.530
# rubbishbladder: 14.070
# batchquickest: 13.750
# completionskylark: 18.311
# fattyoddball: 25.228
# mincegaiters: 23.007
# bismuthcolloquial: 25.809
# freelysociable: 23.668
# fizzlehelp: 25.673
# snaildossier: 30.416
# stunassured: 31.787
# alloweruptions: 27.612
# fizzlehelp: 26.500
# lickerbond: 27.568
# bunchmeats: 22.996
# chiselleddessicants: 15.940
# translatecyclist: 14.740
# feverspolystyrene: 23.374
# deficientclunking: 16.611
# alloweruptions: 16.569
# apronextension: 17.448
# smackswallow: 4.584
# ashamedmuscles: 16.243
# parallelconcerned: 3.077
# nursingrash: 10.433
# pancakesgrebe: 13.723
# frequencywould: 21.220
# cuboidpass: -3.314
# strungebay: 14.589
# fattyoddball: 9.928
# starbucksbluetail: 10.871
# starbucksbluetail: 12.545
# bracesworkable: 15.340
# worldlyventuri: 11.472
# pancakesgrebe: 12.141
# heomicron: 32.324
# latticelaboratory: -4.579
# meggingswine: -3.893
# latticelaboratory: -4.470
# duexslt: -4.129
# fizzclimbing: 20.835
# feverspolystyrene: 17.287
# behaviourverbena: 28.949
# coatprecious: 28.352
# instantthwack: 27.549
# cobolglaucous: 28.364
# dronessomersault: 32.863
# decanterbalance: 26.434
# organicmajor: 27.300
# rappelarias: 25.777
# pipetsrockers: 23.571
# raggedshrink: 27.703
# dweebspices: 24.030
# fixnumquicklime: 31.338
# ashamedmuscles: 30.274
# surmiseteenagers: 29.810
# europiumcentury: -3.726
# clucklinnet: -4.336
# actuallyfoot: -1.904
# flinkjordan: -2.751
# amuckpoints: -0.412
# replacedbevy: 2.379
# burntrifle: 0.352
# poundingfrustum: 0.084
# blythpulse: 7.073
# crepegrape: 7.147
# behaviourverbena: 5.184
# unicyclistamiable: 9.305
# tendonwench: 2.652
# cartridgesbummage: 2.150
# fizzlehelp: 2.972
# poundingfrustum: 7.464
# worldlyventuri: 3.903
# musicalchampagne: 13.648
# sociablelemma: -3.219
# souffleutility: -0.734
# shrillbanjos: -0.961
# singesculptor: -6.208
# guavaconfide: -6.752
# binomialapathetic: -8.058
# somethingalbedo: -7.696
# clucklinnet: -8.221
# looroasting: 47.777
# alloweruptions: 47.730
# grabbig: 43.630
# stairsgobsmacked: 52.920
# barnevidence: 48.930
# microwavejar: 51.479
# geologybeeping: 42.692
# langeredsubset: 49.954
# loindecorate: 76.320
# heomicron: 44.483
# sortinterior: 50.955
# quadratcranky: 53.001
# trapdoormongrel: 44.605
# opticsdiameter: 25.994
# casesslippery: 53.607
# poundingfrustum: 55.330
# tubingwheatear: 42.082
# babyambitious: -44.135
# replacedbevy: 61.133
# burntrifle: 53.988
# heaterinert: 61.528
# stairsgobsmacked: 61.032
# badgefields: 60.978
# allocatesposts: 65.198
# turnoverlovesick: 58.378
# meatsoffbeat: 58.547
# compareas: 63.519
# dronessomersault: 62.748
# cranniescigarette: 56.784
# croutonwrack: 61.855
# shrillbanjos: 35.643
# snowdonevasive: 35.059
# apronextension: 34.643
# sectionssqueaky: 35.931
# epsiloncloning: -41.603
# rigelpaunchy: 38.731
# actuallyfoot: 38.661
# snowdonevasive: 35.559
# burntrifle: 35.646
# heaterinert: 35.493
# babyambitious: 35.585
# fizzclimbing: 41.825
# latticelaboratory: 50.876
# eminentallergy: 50.076
# croutonwrack: 35.288
# radicandoceanic: 47.493
# troubledseptum: 52.366
# popmatrices: 41.459
# wisefumbling: 45.823
# babyambitious: 49.955
# wordsundress: 49.027
# axlevirtue: 45.076
# loindecorate: 47.408
# langeredsubset: 39.867
# emeraldclippers: 45.884
# guavaconfide: 27.582
# actuallyfoot: 28.171
# heomicron: 26.446
# ellipticalfabricator: 49.584
# looroasting: 46.123
# simplicityfairy: 38.940
# xslhopeful: 51.716
# bracesworkable: 40.839
# globeshameful: 43.386
# langeredsubset: 36.473
# flakyunlawful: 41.211
# quadratcranky: 48.143
# europiumcentury: 33.266
# raggedshrink: 32.325
# gnarledbaggy: 29.582
# metaiota: 28.083
# hypergalaxyfibula: 33.645
# croutonwrack: 32.442
# badgefields: 29.843
# flickcanapes: 30.488
# eontop: 34.554
# ischemicfrosted: 33.979
# rigelpaunchy: 33.003
# badgefields: 32.486
# strungebay: 58.013
# radicandoceanic: 35.350
# binomialapathetic: 61.135
# gammagot: 70.085
# privacyhaunt: 68.864
# grabbig: 66.919
# dampedbrioche: 66.101
# dampedbrioche: 68.032
# pipetsrockers: 71.057
# metaiota: 68.500
# mtvgrosbeak: 67.204
# simplicityfairy: 67.578
# bismuthcolloquial: 60.830
# dronessomersault: 64.178
# analbar: 64.273
# compareas: 58.816
# pancakesgrebe: 59.883
# radicandoceanic: 59.787
# figsql: 59.837
# nursingrash: 62.676
# applyingbaker: 61.812
# troubledseptum: 59.455
# applyingbaker: 60.332
# tendonwench: 37.085
# mincegaiters: 37.724
# duexslt: 34.474
# unguardedgiant: 37.529
# casesslippery: 32.993
# lymphomamellow: 40.390
# risottospell: 43.376
# binomialapathetic: 32.070
# binomialapathetic: 34.925
# freelysociable: 33.498
# looroasting: 44.662
# coatprecious: 33.411
# copalinstruct: 36.570
# compareas: 40.246
# earmarinated: 30.685
# bunchmeats: 36.963
# casesslippery: 60.448
# evaporatingplug: 36.927
# frequencywould: 32.176
# compareas: 44.081
# loindecorate: 31.559
# popmatrices: 36.434
# buoyancycowardice: 41.124
# quadratcranky: 36.721
# farrowcetti: 42.315
# specifiedinnovative: 30.296
# geologybeeping: 35.450
# microwavejar: 42.302
# geologybeeping: 42.290
# gammagot: 44.121
# rubbishbladder: 41.566
# strungebay: 34.481
# spiritedjump: 43.748
# metaiota: 37.051
# burntrifle: 39.008
# twitequiver: 36.854
# turnoverlovesick: 36.586
# decanterbalance: 40.158
# figsql: 33.605
# bunchmeats: 39.607
# specifiedinnovative: 40.625
# compareas: 31.525
# dotwazzack: 52.917
# cleaningburnt: 52.898
# dronessomersault: 51.603
# evaporatingplug: 48.158
# lickerbond: 52.669
# worldlyventuri: 52.138
# chiselleddessicants: 53.787
# europiumcentury: 52.260
# actuallyfoot: 44.765
# tyrespan: 43.408
# badgefields: 44.113
# snaildossier: 45.344
# chiselleddessicants: 44.913
# handywrist: 45.341
# alloweruptions: 46.894
# ytterbiumprovincial: 48.587
# impetuousfurbelows: 47.042
# gilletteclammy: 43.404
# fattyoddball: 45.910
# ceilinjuries: 44.993
# smackswallow: 42.961
# dronessomersault: 44.712
# strungebay: 43.172
# neckedjre: 45.951
# applyingbaker: 46.620
# meatsoffbeat: 46.014
# peacefulceaseless: 41.945
# flakyunlawful: 45.827
# rubbishbladder: 44.111
# singesculptor: 43.486
# unicyclistamiable: 46.027
# freelysociable: 45.845
# cuboidpass: 45.085
# worldlyventuri: 47.172
# surmiseteenagers: 45.782
# unbalancedprotoplanet: 46.891
# easybobolink: 47.959
# gogglesknacker: 45.156
# rubbishbladder: 44.656
# radicandoceanic: 42.972
# singesculptor: 43.464
# unbalancedprotoplanet: 45.404
# instantthwack: 44.289
# flakyunlawful: 44.848
# flakyunlawful: 44.786
# stairsgobsmacked: 44.699
# rigelpaunchy: 44.905
# starbucksbluetail: 45.136
# freelysociable: 49.867
# binomialapathetic: 44.388
# evaporatingplug: 46.231
# hypergalaxyfibula: 52.912
# smackswallow: 55.469
# canalhateful: 51.899
# copalinstruct: 52.466
# farrowcetti: 51.384
# europiumcentury: 54.591
# peacefulceaseless: 48.916
# analbar: 48.844
# instantthwack: 48.070
# micaassistant: 51.493
# cranniescigarette: 50.537
# applyingbaker: 49.958
# nursingrash: 46.569
# poohvireo: 46.693
# starbucksbluetail: 55.233
# alloweruptions: 52.036
# hoursethanoate: 51.324
# dronessomersault: 50.598
# musicalchampagne: 50.727
# cranniescigarette: 50.550
# peacefulceaseless: 51.330
# analbar: 51.487
# decanterbalance: 51.347
# sociablelemma: 51.518
# meatsoffbeat: 48.956
# moderatohorn: 49.428
# microwavejar: 51.537
# gogglesknacker: 51.644
# tyrespan: 52.460
# neckedjre: 50.817
# sortinterior: 51.091
# burritoscarriage: 50.426
# organicmajor: 50.060
# twitequiver: 52.028
# wisefumbling: 50.692
# dweebspices: 48.923
# producecoven: 49.891
# heomicron: 49.573
# bluetailgodwottery: 47.313
# opticsdiameter: 48.593
# decanterbalance: 50.671
# carrionscream: 48.873
# gammagot: 49.772
# rappelarias: 50.496
# neighborlyrook: 49.837
# quadratcranky: 48.447
# listenerabandoned: 45.522
# rigelpaunchy: 48.649
# historypant: 50.874
# gruntdrive: 49.007
# latticelaboratory: 45.611
# parallelconcerned: 49.038
# figsql: 48.212
# bonelliseal: 47.539
# poundingfrustum: 46.677
# wonderfulscullian: 48.809
# completionskylark: 48.716
# dotwazzack: 45.910
# pipeathlete: 48.035
# opticsdiameter: 49.108
# showerspain: 49.686
# applyingbaker: 51.567
# trapdoormongrel: 49.435
# lymphomamellow: 47.142
# hoovessquares: 50.249
# peacefulceaseless: 49.622
# dweebspices: 51.975
# driftmvc: 49.748
# pipeathlete: 52.961
# maintainwiggly: 50.559
# worldlyventuri: 48.160
# backedammeter: 46.205
# organicmajor: 47.288
# cartridgesbummage: 50.060
# cleaningburnt: 51.411
# rubbishbladder: 51.773
# troubledseptum: 51.563
# flinkjordan: 51.854
# rigelpaunchy: 51.276
# barnevidence: 50.858
# hoursethanoate: 51.085
# cranniescigarette: 51.137
# mtvgrosbeak: 50.976
# showerspain: 53.365
# gilletteclammy: 52.339
# tendonwench: 55.137
# wonderfulscullian: 54.899
# upbeatodd: 51.228
# casesslippery: 50.116
# bluetailgodwottery: 53.376
# synonympatisserie: 54.344
# freelysociable: 53.290
# specifiedinnovative: 55.967
# unicyclistamiable: 53.651
# tweezerscurve: 53.261
# upbeatodd: 54.431
# babyambitious: 53.842
# tweezerscurve: 44.029
# applyingbaker: 48.180
# crepegrape: 46.508
# planktonuses: 44.943
# gaudyfea: 47.319
# europiumcentury: 49.520
# earmarinated: 44.321
# deficientclunking: 45.323
# dialgraft: 44.379
# specifiedinnovative: 48.723
# frequencywould: 43.837
# cleaningburnt: 48.150
# crepegrape: 46.335
# fixnumquicklime: 45.283
# ashamedmuscles: 43.807
# spiritedjump: 45.542
# sectionssqueaky: 45.683
# bunchmeats: 44.787
# dialgraft: 45.005
# realtorcaustic: 45.163
# twitequiver: 55.119
# globeshameful: 55.322
# shrillbanjos: 52.359
# unguardedgiant: 55.203
# wordsundress: 54.395
# pleasinghoop: 56.612
# freelysociable: 53.535
# showerspain: 54.278
# disjointtoday: 54.923
# epsiloncloning: 54.538
# poundingfrustum: 53.231
# gruntdrive: 53.360
# casesslippery: 56.167
# bashrower: 54.147
# frequencywould: 49.374
# specifiedinnovative: 49.243
# bracesworkable: 48.174
# impetuousfurbelows: -9.285
# unbalancedprotoplanet: -9.410
# lasttaiga: 51.316
# lickerbond: 53.750
# barnevidence: 59.213
# peacefulceaseless: 59.953
# wonderfulscullian: 66.812
# chichazard: 63.140
# burntrifle: 62.014
# wisefumbling: 61.620
# radicandoceanic: 64.484
# gogglesknacker: 60.519
# burritoscarriage: 60.520
# fizzlehelp: 61.728
# gruntdrive: 59.291
# heaterinert: 58.621
# gogglesknacker: 59.094
# ellipticalfabricator: 65.314
# listenerabandoned: 63.885
# snowdonevasive: 62.567
# cobolglaucous: 59.514
# heaterinert: 62.331
# parallelconcerned: 65.533
# poundingfrustum: 62.127
# ytterbiumprovincial: 63.985
# burritoscarriage: 65.153
# tyrespan: 62.116
# apronextension: 61.347
# disjointtoday: 62.783
# trapdoormongrel: 65.655
# showerspain: 59.691
# craytugofwar: 64.492
# shrillbanjos: 64.492
# cheapersyllable: 59.577
# compareas: 59.681
# axlevirtue: 62.681
# hoursethanoate: 64.602
# submittedwavelength: 52.100
# meatsoffbeat: 59.500
# behaviourverbena: 61.879
# barnevidence: 61.317
# driftmvc: 62.247
# sectionssqueaky: 63.455
# parallelconcerned: 61.905
# hypergalaxyfibula: 60.519
# organicmajor: 59.934
# looroasting: 63.491
# expecteffective: 61.893
# bismuthcolloquial: 58.635
# ischemicfrosted: 66.693
# actuallyfoot: 69.104
# fizzclimbing: 66.667
# emeraldclippers: 69.676
# cheapersyllable: 65.073
# behaveterminal: -42.578
# barnevidence: 65.046
# fattyoddball: 67.358
# stunassured: 57.259
# cuboidpass: 56.077
# globeshameful: 57.899
# risottospell: 56.968
# epsiloncloning: 57.921
# farrowcetti: 58.373
# bonelliseal: 56.613
# gogglesknacker: 58.605
# planktonuses: 57.701
# mtvgrosbeak: 55.148
# shrillbanjos: 52.533
# cranesurgeon: 48.116
# cranniescigarette: 48.785
# coatprecious: 51.267
# lymphomamellow: 51.424
# quadratcranky: 53.723
# namibianstabbing: 50.399
# synonympatisserie: 52.324
# evaporatingplug: 48.923
# fixnumquicklime: 48.327
# burritoscarriage: 48.306
# quadratcranky: 50.416
# earmarinated: 49.602
# flinkjordan: 52.690
# colonclipper: 54.746
# starbucksbluetail: 54.359
# flinkjordan: 55.378
# cowardlyabout: 52.850
# craytugofwar: 52.178
# bracesworkable: 53.251
# bonelliseal: 54.722
# gaudyfea: 54.199
# rubbishbladder: 55.121
# cartridgesbummage: 54.636
# translatecyclist: -36.852
# phobosstaccato: 52.170
# impetuousfurbelows: 58.628
# applyingbaker: 57.787
# strungebay: 56.531
# stunassured: 55.824
# unicyclistamiable: 57.843
# snowdonevasive: 59.028
# apronextension: 56.265
# troubledseptum: 55.700
# cowardlyabout: 56.400
# opticsdiameter: 55.759
# pipetsrockers: 59.300
# advisorlanguage: 56.632
# copalinstruct: 57.768
# wisefumbling: 57.103
# compareas: 57.244
# apronextension: 56.284
# smackswallow: 57.857
# fundingticket: 54.511
# ischemicfrosted: 54.394
# maintainwiggly: 54.100
# bismuthcolloquial: 54.055
# behaveterminal: 54.731
# upbeatodd: 53.000
# grabbig: 54.451
# gravelscientific: 55.143
# cowardlyabout: 55.177
# sectionssqueaky: 54.077
# gogglesknacker: 55.015
# submittedwavelength: 53.832
# gaudyfea: 54.451
# submittedwavelength: 54.494
# neckedjre: 55.609
# handywrist: 61.430
# tubingwheatear: 60.681
# batchquickest: 62.166
# hoursethanoate: 59.088
# actuallyfoot: 61.589
# expecteffective: 63.374
# apronextension: 65.321
# pipeathlete: 66.098
# canalhateful: 63.742
# burritoscarriage: 64.665
# deficientclunking: 66.469
# decanterbalance: 63.118
# micaassistant: 62.950
# sociablelemma: 65.547
# backedammeter: 67.807
# rappelarias: 65.291
# instantthwack: 65.752
# ceilinjuries: 63.821
# flickcanapes: 66.831
# synonympatisserie: 64.361
# disjointtoday: 65.846
# gravelscientific: 64.612
# carrionscream: 66.898
# handywrist: 66.010
# pleasinghoop: 66.661
# neighborlyrook: 67.448
# translatecyclist: 64.521
# fizzlehelp: 65.825
# neckedjre: 67.852
# strungebay: 66.490
# sortinterior: 68.553
# strungebay: 67.826
# canalhateful: 66.717
# upbeatodd: 66.221
# meatsoffbeat: 64.876
# wonderfulscullian: 67.845
# heomicron: 65.443
# bonelliseal: 66.897
# hoursethanoate: 50.335
# privacyhaunt: 64.103
# troubledseptum: 62.224
# bunchmeats: 62.431
# langeredsubset: 58.604
# strungebay: 62.421
# peacefulceaseless: 60.798
# trapdoormongrel: 64.680
# starbucksbluetail: 60.980
# binomialapathetic: 61.947
# starbucksbluetail: 29.853
# somethingalbedo: 11.801
# showerspain: 35.151
# pipetsrockers: 30.147
# completionskylark: 33.142
# gilletteclammy: 31.687
# earmarinated: 29.370
# ellipticalfabricator: 32.785
# eminentallergy: 30.644
# eminentallergy: 8.324
# bunchmeats: 29.049
# crepegrape: 11.062
# guavaconfide: 9.804
# fattyoddball: 11.671
# ischemicfrosted: 30.944
# lickerbond: 29.668
# rubbishbladder: 32.270
# worldlyventuri: 12.043
# frequencywould: 10.113
# canalhateful: 28.565
# looroasting: 32.567
# clucklinnet: 16.723
# snaildossier: 29.645
# cleaningburnt: 10.490
# dampedbrioche: 29.491
# sectionssqueaky: 31.111
# wordsundress: 33.554
# gilletteclammy: 32.837
# risottospell: -73.146
# heaterinert: 61.129
# flickcanapes: 62.156
# submittedwavelength: 67.439
# babyambitious: 73.432
# compareas: 71.128
# parallelconcerned: 70.605
# nursingrash: 72.851
# surmiseteenagers: 70.471
# pleasinghoop: 67.673
# fizzlehelp: 68.207
# risottospell: 74.799
# ashamedmuscles: 68.928
# axlevirtue: 70.674
# paddlevacuole: 69.877
# swankythough: 70.589
# producecoven: 74.042
# peacefulceaseless: 73.777
# troubledseptum: 70.880
# maintainwiggly: 67.148
# producecoven: 53.877
# popmatrices: 52.347
# wonderfulscullian: 53.738
# dialgraft: 53.546
# rappelarias: 55.228
# upbeatodd: 56.047
# showerspain: 55.397
# paddlevacuole: 56.144
# poundingfrustum: 54.853
# latticelaboratory: 53.758
# hoovessquares: 55.374
# heomicron: 54.915
# lasttaiga: 54.411
# pleasinghoop: 54.599
# dotwazzack: 56.014
# troubledseptum: 57.046
# xslhopeful: 56.418
# stylishmugs: 72.676
# apronextension: 73.123
# dronessomersault: 72.638
# canalhateful: 72.645
# nursingrash: 72.263
# advisorlanguage: 72.428
# neckedjre: 69.328
# binomialapathetic: 67.699
# mincegaiters: 74.426
# translatecyclist: 72.727
# canalhateful: 70.541
# grabbig: 76.608
# replacedbevy: 76.351
# gaudyfea: 76.717
# babyambitious: 76.526
# mincegaiters: 74.266
# specifiedinnovative: 70.817
# meatsoffbeat: 76.677
# bluetailgodwottery: 67.487
# duexslt: 69.792
# gogglesknacker: 67.545
# hypergalaxyfibula: 68.296
# producecoven: -90.061
# dotwazzack: 70.366
# historypant: 65.449
# wisefumbling: 65.478
# pleasinghoop: 65.523
# listenerabandoned: 68.367
# planktonuses: 69.444
# dialgraft: 70.060
# bashrower: 70.818
# langeredsubset: 65.506
# popmatrices: 66.643
# metaiota: -65.396
# dotwazzack: 64.810
# wonderfulscullian: 70.210
# synonympatisserie: 77.898
# completionskylark: 78.095
# flickcanapes: 79.237
# apronextension: 81.127
# blythpulse: 80.785
# actuallyfoot: -69.384
# frequencywould: 81.801
# alloweruptions: 79.046
# guavaconfide: 79.819
# musicalchampagne: 65.495
# rubbishbladder: 65.280
# frequencywould: 75.620
# neighborlyrook: 75.859
# paddlevacuole: 61.922
# globeshameful: 63.583
# axlevirtue: 30.802
# hoovessquares: 65.128
# wonderfulscullian: 65.191
# evaporatingplug: 61.611
# fattyoddball: 63.609
# canalhateful: 61.128
# duexslt: 66.457
# easybobolink: 65.383
# gammagot: 69.904
# neckedjre: 65.520
# planktonuses: 66.454
# expecteffective: 67.772
# cobolglaucous: 66.857
# micaassistant: 69.315
# elatedunicorn: -46.433
# bunchmeats: -50.022
# specifiedinnovative: -50.492
# micaassistant: -50.013
# buoyancycowardice: -50.231
# smackswallow: -52.869
# tendonwench: -53.716
# nursingrash: -50.461
# poundingfrustum: -49.796
# ashamedmuscles: -50.812
# fixnumquicklime: -51.239
# somethingalbedo: -51.258
# bashrower: -51.199
# apronextension: -73.364
# flinkjordan: -74.938
# wordsundress: -75.944
# paddlevacuole: -77.176
# figsql: -76.900
# behaviourverbena: -71.111
# axlevirtue: -72.471
# axlevirtue: -69.461
# worldlyventuri: -70.206
# alloweruptions: -71.700
# risottospell: -73.156
# ischemicfrosted: -70.011
# ellipticalfabricator: -58.565
# dampedbrioche: -58.852
# badgefields: -59.410
# behaveterminal: -58.336
# lasttaiga: -58.835
# cowardlyabout: -82.997
# quadratcranky: -74.372
# expecteffective: -80.612
# fixnumquicklime: -80.487
# stunassured: -80.427
# starbucksbluetail: -71.767
# producecoven: -73.145
# bunchmeats: -77.478
# stairsgobsmacked: -81.941
# cheapersyllable: -82.710
# dweebspices: -69.822
# musicalchampagne: -82.440
# raggedshrink: -70.684
# axlevirtue: -74.793
# twitequiver: -77.262
# canalhateful: -75.253
# badgefields: -45.332
# gaudyfea: -66.403
# croutonwrack: -80.404
# dronessomersault: -83.423
# opticsdiameter: -84.807
# ceilinjuries: -82.789
# evaporatingplug: -82.956
# disjointtoday: -78.923
# ischemicfrosted: -81.952
# craytugofwar: -84.300
# pancakesgrebe: -65.495
# handywrist: -75.379
# microwavejar: -78.644
# europiumcentury: -84.219
# shrillbanjos: -83.396
# completionskylark: -80.487
# copalinstruct: -86.290
# rubbishbladder: -85.359
# cobolglaucous: -71.755
# cuboidpass: -68.721
# duexslt: -82.611
# organicmajor: -81.176
# hypergalaxyfibula: -76.477
# hoursethanoate: -74.514
# simplicityfairy: -79.636
# privacyhaunt: -74.328
# flickcanapes: -83.105
# feverspolystyrene: -79.750
# peacefulceaseless: -72.127
# ellipticalfabricator: -79.727
# globeshameful: -76.858
# fundingticket: -79.213
# gruntdrive: -78.706
# meatsoffbeat: -82.174
# meatsoffbeat: -71.908
# wonderfulscullian: -82.642
# sortinterior: -84.574
# burntrifle: -81.212
# hoursethanoate: -79.568
# handywrist: -72.220
# pancakesgrebe: -86.569
# globeshameful: -83.878
# flickcanapes: -78.677
# guavaconfide: -78.636
# dampedbrioche: -76.433
# snaildossier: -77.842
# eminentallergy: -76.464
# rubbishbladder: -84.429
# strungebay: -75.569
# expecteffective: -76.768
# chichazard: -80.229
# belchedsodding: -77.576
# gammagot: -65.841
# stairsgobsmacked: -74.820
# alloweruptions: -77.041
# surmiseteenagers: -79.790
# nursingrash: -83.859
# looroasting: -82.231
# metaiota: -85.414
# belchedsodding: -82.709
# nursingrash: -71.783
# farrowcetti: -74.164
# meggingswine: -74.474
# shrillbanjos: -74.027
# epsiloncloning: -69.340
# snaildossier: -72.910
# listenerabandoned: -73.058
# lickerbond: -74.044
# radicandoceanic: -70.685
# bracesworkable: -70.582
# behaviourverbena: -72.860
# metaiota: -70.312
# bonelliseal: -74.166
# moderatohorn: -78.984
# simplicityfairy: -74.367
# raggedshrink: -74.791
# copalinstruct: -45.001
# poohvireo: -73.270
# maintainwiggly: -74.591
# compareas: -74.527
# simplicityfairy: -73.580
# ledgeindeed: -74.951
# tyrespan: -73.671
# worldlyventuri: -73.064
# showerspain: -75.677
# craytugofwar: -74.215
# stunassured: -73.251
# guavaconfide: -74.518
# xslhopeful: -74.687
# smackswallow: -73.425
# mtvgrosbeak: -74.133
# namibianstabbing: -75.615
# burntrifle: -75.420
# gogglesknacker: -55.517
# freelysociable: -52.462
# lickerbond: -54.277
# ceilinjuries: -53.712
# allegatorwafers: -54.141
# raggedshrink: -56.225
# popmatrices: -56.763
# wordsundress: -55.867
# smackswallow: -58.264
# expecteffective: -59.930
# unicyclistamiable: -56.427
# frequencywould: -55.866
# metaiota: -56.703
# babyambitious: -55.301
# wonderfulscullian: -55.073
# amuckpoints: -59.420
# tyrespan: -55.530
# epsiloncloning: -61.306
# strungebay: -54.268
# driftmvc: -56.801
# easybobolink: -60.949
# metaiota: -59.547
# advisorlanguage: -61.257
# listenerabandoned: -59.638
# historypant: -57.451
# clucklinnet: -55.511
# stunassured: -61.313
# chichazard: -57.473
# lasttaiga: -45.775
# rappelarias: -58.401
# planktonuses: -55.948
# tendonwench: -60.196
# earmarinated: -62.065
# dampedbrioche: -53.397
# moderatohorn: -53.097
# namibianstabbing: -50.572
# mtvgrosbeak: -52.995
# parallelconcerned: -51.529
# earmarinated: -51.391
# namibianstabbing: -50.646
# tendonwench: -52.464
# fattyoddball: -52.102
# smackswallow: -53.565
# backedammeter: -46.772
# shrillbanjos: -52.315
# impetuousfurbelows: -52.315
# dampedbrioche: -51.209
# surmiseteenagers: -51.046
# microwavejar: -52.226
# frequencywould: -51.286
# figsql: -52.270
# surmiseteenagers: -52.137
# pancakesgrebe: -52.692
# mincegaiters: -51.915
# pancakesgrebe: -51.689
# epsiloncloning: -50.634
# batchquickest: -52.427
# metaiota: -53.548
# coatprecious: -51.152
# meatsoffbeat: -50.461
# replacedbevy: -70.769
# craytugofwar: -178.595
# poohvireo: -181.008
# crepegrape: 159.688
# sortinterior: 160.516
# unicyclistamiable: -196.391
# heomicron: -192.547
# tubingwheatear: 174.529
# langeredsubset: 173.551
# lasttaiga: 118.785
# driftmvc: -189.438
# moderatohorn: -185.838
# backedammeter: -185.041
# smackswallow: -173.795
# submittedwavelength: -172.889
# advisorlanguage: -162.863
# handywrist: -156.707
# neckedjre: -163.350
# nursingrash: -154.906
# unbalancedprotoplanet: -161.711
# surmiseteenagers: -160.507
# fattyoddball: -157.970
# europiumcentury: -162.548
# decanterbalance: -160.242
# lickerbond: -153.622
# raggedshrink: -159.955
# horsesmultiply: -161.865
# gilletteclammy: -163.585
# turnoverlovesick: -159.480
# latticelaboratory: -149.024
# wisefumbling: -46.525
# batchquickest: -168.196
# xslhopeful: -162.615
# namibianstabbing: -167.709
# dronessomersault: -167.252
# bluetailgodwottery: -159.021
# applyingbaker: -168.670
# loindecorate: -168.189
# flinkjordan: 150.620
# flinkjordan: 143.784
# ceilinjuries: 143.709
# clucklinnet: 146.465
# gilletteclammy: 144.215
# gogglesknacker: 146.556
# belchedsodding: 144.469
# sectionssqueaky: 145.932
# flickcanapes: 144.198
# strungebay: 137.784
# namibianstabbing: 137.345
# pancakesgrebe: 137.944
# unguardedgiant: 129.043
# turnoverlovesick: -220.267
# bracesworkable: 124.270
# unguardedgiant: 139.315
# phobosstaccato: 126.222
# flinkjordan: 128.272
# wonderfulscullian: 137.465
# singesculptor: 137.120
# spiritedjump: 138.649
# flickcanapes: 138.215
# europiumcentury: 124.162
# dronessomersault: 126.368
# fixnumquicklime: 122.117
# paddlevacuole: 134.660
# showerspain: 135.171
# wordsundress: 131.923
# copalinstruct: 121.901
# dweebspices: 135.182
# strungebay: 126.112
# ceilinjuries: 135.296
# rappelarias: 134.084
# completionskylark: 123.718
# elatedunicorn: 138.208
# organicmajor: 136.212
# gruntdrive: -90.000
# snowdonevasive: 138.524
# worldlyventuri: 126.922
# tubingwheatear: 125.883
# actuallyfoot: 132.352
# compareas: 89.189
# actuallyfoot: 124.523
# specifiedinnovative: 129.002
# dweebspices: 138.994
# peacefulceaseless: 133.478
# gilletteclammy: 138.400
# badgefields: 137.843
# duexslt: 138.597
# cranniescigarette: 129.843
# epsiloncloning: 135.063
# looroasting: 96.438
# bunchmeats: 104.898
# submittedwavelength: 103.778
# horsesmultiply: 97.354
# stairsgobsmacked: 100.692
# feverspolystyrene: 103.917
# pipetsrockers: 95.652
# cowardlyabout: 102.664
# historypant: 105.576
# pipetsrockers: 76.904
# colonclipper: 76.509
# synonympatisserie: 60.897
# casesslippery: 74.770
# microwavejar: 61.930
# instantthwack: 62.605
# surmiseteenagers: 75.503
# colonclipper: 76.269
# fixnumquicklime: 76.417
# stylishmugs: 59.487
# allocatesposts: 70.077
# copalinstruct: 68.691
# troubledseptum: 69.124
# flakyunlawful: 76.444
# completionskylark: 60.521
# unbalancedprotoplanet: 60.836
# driftmvc: 73.429
# fizzclimbing: 64.258
# mtvgrosbeak: 62.031
# emeraldclippers: 74.460
# ellipticalfabricator: 72.663
# upbeatodd: 69.675
# cleaningburnt: 65.143
# figsql: 61.772
# allegatorwafers: 73.117
# badgefields: 71.656
# decanterbalance: 76.691
# ytterbiumprovincial: 72.045
# pancakesgrebe: 76.754
# expecteffective: 64.588
# sortinterior: 117.048
# gilletteclammy: 66.084
# replacedbevy: 64.984
# deficientclunking: 62.028
# loindecorate: 71.854
# casesslippery: 76.637
# canalhateful: 70.424
# easybobolink: -45.282
# loindecorate: 62.675
# wisefumbling: 62.208
# flinkjordan: 78.599
# hoovessquares: 80.832
# cheapersyllable: 80.422
# frequencywould: 81.166
# realtorcaustic: 81.273
# belchedsodding: 80.370
# compareas: 79.708
# neighborlyrook: 80.099
# dotwazzack: 80.909
# singesculptor: 79.779
# alloweruptions: 81.531
# souffleutility: 80.097
# singesculptor: 80.506
# ischemicfrosted: 81.357
# badgefields: 79.584
# pancakesgrebe: 80.448
# gruntdrive: 80.167
# coatprecious: 81.504
# maintainwiggly: 82.255
# croutonwrack: 84.490
# axlevirtue: 84.259
# ytterbiumprovincial: 85.472
# farrowcetti: 84.612
# microwavejar: 84.318
# hypergalaxyfibula: 86.931
# backedammeter: -45.153
# maintainwiggly: 83.985
# expecteffective: 86.403
# figsql: 85.790
# producecoven: 87.178
# feverspolystyrene: 86.568
# meggingswine: 87.026
# poundingfrustum: 87.003
# dotwazzack: 86.287
# cleaningburnt: 86.657
# hoursethanoate: 83.596
# wonderfulscullian: 86.397
# looroasting: 87.226
# unbalancedprotoplanet: 83.331
# croutonwrack: 82.657
# wonderfulscullian: 85.224
# micaassistant: 92.164
# opticsdiameter: 97.566
# pipetsrockers: 91.530
# canalhateful: 128.479
# gruntdrive: 90.560
# gravelscientific: 92.835
# namibianstabbing: 87.589
# planktonuses: -92.784
# namibianstabbing: 82.615
# figsql: 82.166
# gravelscientific: 80.562
# tubingwheatear: 82.129
# burritoscarriage: 83.401
# allegatorwafers: 43.626
# showerspain: 84.369
# dotwazzack: 85.133
# twitequiver: 86.181
# fattyoddball: 92.642
# elatedunicorn: 85.825
# globeshameful: 90.382
# phobosstaccato: 87.956
# poundingfrustum: 89.735
# horsesmultiply: 67.716
# gammagot: 67.964
# tweezerscurve: 64.630
# dotwazzack: 69.310
# realtorcaustic: 67.084
# ledgeindeed: 68.616
# dialgraft: 77.195
# snowdonevasive: 69.309
# ashamedmuscles: 70.601
# blythpulse: 79.084
# somethingalbedo: 78.886
# feverspolystyrene: 76.538
# carrionscream: 76.801
# copalinstruct: 48.738
# bunchmeats: 78.796
# paddlevacuole: 77.340
# horsesmultiply: 78.020
# rigelpaunchy: 77.939
# tendonwench: 80.617
# meggingswine: 81.436
# wordsundress: 81.552
# eminentallergy: 80.846
# sectionssqueaky: 82.412
# pipeathlete: 79.566
# globeshameful: 81.878
# mtvgrosbeak: 71.130
# applyingbaker: 71.691
# moderatohorn: 105.005
# craytugofwar: 7.900
# binomialapathetic: 51.000
# decanterbalance: 104.360
# translatecyclist: 87.563
# maintainwiggly: 110.252
# somethingalbedo: 96.734
# expecteffective: 92.067
# ceilinjuries: 105.925
# deficientclunking: 105.841
# chichazard: 106.688
# shrillbanjos: 107.848
# crepegrape: 104.134
# xslhopeful: 95.478
# strungebay: 91.832
# turnoverlovesick: 101.622
# chichazard: 94.609
# dampedbrioche: 104.099
# frequencywould: 91.087
# rigelpaunchy: 88.636
# unguardedgiant: 105.508
# ...
# paddlevacuole: -38.480
# moderatohorn: -36.632
# rubbishbladder: -36.632
# croutonwrack: -112.595
# agenascientists: 76.305
# croutonwrack: 79.068
# bluetailgodwottery: 76.477
# craytugofwar: 155.792
# expecteffective: 158.920
# heomicron: 137.958
# phobosstaccato: 58.569
# actuallyfoot: 93.449
# croutonwrack: 125.106
# dweebspices: 70.087
# gaudyfea: -33.885
# feverspolystyrene: -65.581
# disjointtoday: -91.995
# namibianstabbing: 50.789
# shrillbanjos: -65.186
# strungebay: 64.972
# emeraldclippers: 60.595
# hypergalaxyfibula: 66.314
# translatecyclist: 157.720
# gogglesknacker: 55.739
# surmiseteenagers: 57.324
# singesculptor: 55.521
# producecoven: 56.510
# pleasinghoop: 54.760
# craytugofwar: -84.654
# completionskylark: 80.557
# replacedbevy: 207.804
# dotwazzack: 65.665
# planktonuses: 56.393
# privacyhaunt: -78.267
# disjointtoday: -78.491
# simplicityfairy: -77.305
# sectionssqueaky: 55.257
# lasttaiga: 56.345
# ytterbiumprovincial: -78.929
# mtvgrosbeak: -78.830
# producecoven: 152.277
# freelysociable: -40.683
# gravelscientific: 145.434
# swankythough: 142.584
# behaveterminal: -0.964
# flakyunlawful: 64.304
# phobosstaccato: 57.905
# synonympatisserie: 54.526
# dampedbrioche: 53.887
# snaildossier: 57.210
# applyingbaker: 66.586
# pipetsrockers: 61.783
# duexslt: 115.169
# pleasinghoop: 139.847
# radicandoceanic: -58.178
# cheapersyllable: -58.800
# flickcanapes: 74.164
# pipeathlete: -58.107
# tweezerscurve: 51.855
# belchedsodding: 56.411
# bluetailgodwottery: 51.236
# tweezerscurve: 57.536
# ellipticalfabricator: 57.642
# gogglesknacker: 57.199
# gruntdrive: -31.100
# surmiseteenagers: -75.178
# badgefields: -52.855
# unbalancedprotoplanet: -85.183
# twitequiver: -54.195
# advisorlanguage: -45.602
# cartridgesbummage: 76.475
# musicalchampagne: 60.467
# souffleutility: 70.013
# looroasting: 64.510
# farrowcetti: 54.403
# cuboidpass: 55.124
# quadratcranky: 51.395
# bonelliseal: 1.221
# pipeathlete: -92.447
# poundingfrustum: 136.403
# gaudyfea: 136.441
# souffleutility: 136.634
# stylishmugs: -8.428
# swankythough: 136.389
# meatsoffbeat: 135.817
# impetuousfurbelows: 131.892
# upbeatodd: 115.717
# apronextension: 121.260
# chichazard: 107.048
# popmatrices: -49.907
# popmatrices: 132.128
# opticsdiameter: -52.299
# lickerbond: -51.196
# flickcanapes: 32.435
# cartridgesbummage: 172.735
# globeshameful: -74.992
# coatprecious: -135.420
# raggedshrink: 92.410
# namibianstabbing: 92.261
# gruntdrive: -37.626
# shrillbanjos: 146.627
# bonelliseal: 142.940
# dweebspices: 145.594
# cranniescigarette: 38.461
# organicmajor: -208.416
# musicalchampagne: -31.052
# radicandoceanic: 31.960
# fizzclimbing: 21.711
# souffleutility: 171.649
# pancakesgrebe: 38.919
# microwavejar: 79.009
# privacyhaunt: 81.147
# flakyunlawful: 79.473
# horsesmultiply: 87.409
# batchquickest: -72.128
# completionskylark: -57.988
# hoursethanoate: -71.405
# copalinstruct: -65.196
# feverspolystyrene: -69.779
# freelysociable: 181.749
# cheapersyllable: 53.925
# expecteffective: 53.925
# compareas: -54.526
# decanterbalance: -54.512
# burritoscarriage: 8.078
# gilletteclammy: 76.864
# wisefumbling: 76.839
# emeraldclippers: -66.460
# lasttaiga: 54.045
# gaudyfea: 118.546
# eminentallergy: -97.873
# poohvireo: -91.082
# somethingalbedo: -85.271
# blythpulse: 105.025
# paddlevacuole: 142.295
# popmatrices: 46.759
# translatecyclist: 59.392
# quadratcranky: 161.933
# evaporatingplug: 51.075
# pleasinghoop: 60.117
# flinkjordan: 55.717
# producecoven: 51.352
# bismuthcolloquial: 174.492
# flinkjordan: 123.847
# souffleutility: -70.755
# backedammeter: -84.463
# meggingswine: 131.866
# ellipticalfabricator: 128.479
# microwavejar: 50.500
# unguardedgiant: 52.680
# neckedjre: -39.555
# heaterinert: -67.535
# sociablelemma: -41.312
# gnarledbaggy: 67.514
# looroasting: 67.573
# synonympatisserie: 67.607
# bashrower: 60.920
# babyambitious: 108.964
# disjointtoday: 113.086
# phobosstaccato: 126.006
# cobolglaucous: 139.650
# axlevirtue: 111.861
# hoursethanoate: 111.870
# horsesmultiply: 116.173
# easybobolink: 111.427
# ceilinjuries: 110.022
# hoursethanoate: 138.800
# spiritedjump: 109.221
# axlevirtue: 108.119
# singesculptor: 113.695
# microwavejar: 108.966
# twitequiver: 54.291
# epsiloncloning: 173.393
# gilletteclammy: 168.907
# gnarledbaggy: 166.614
# deficientclunking: 166.624
# shrillbanjos: -119.860
# eminentallergy: -120.650
# buoyancycowardice: -120.300
# bismuthcolloquial: -126.790
# simplicityfairy: -126.830
# twitequiver: -127.787
# applyingbaker: -122.800
# horsesmultiply: -122.974
# allocatesposts: -52.673
# stylishmugs: 9.998
# handywrist: 10.805
# emeraldclippers: 92.520
# binomialapathetic: 132.679
# pipetsrockers: 175.548
# babyambitious: -82.934
# decanterbalance: -86.880
# flickcanapes: -87.872
# frequencywould: -88.401
# driftmvc: -87.903
# advisorlanguage: 156.376
# babyambitious: 155.739
# smackswallow: 152.702
# bracesworkable: 151.557
# apronextension: 154.093
# babyambitious: 153.831
# flinkjordan: 153.861
# advisorlanguage: 154.097
# hoursethanoate: 154.097
# cranesurgeon: 155.607
# sociablelemma: 179.302
# elatedunicorn: 83.849
# binomialapathetic: 76.350
# snaildossier: 69.241
# wordsundress: 92.300
# quadratcranky: 94.992
# popmatrices: 86.992
# shrillbanjos: -28.727
# badgefields: -36.469
# ledgeindeed: -35.955
# pipetsrockers: -35.918
# moderatohorn: 90.743
# cleaningburnt: 138.074
# souffleutility: 77.179
# fizzclimbing: 77.153
# geologybeeping: 33.701
# gruntdrive: 152.579
# burntrifle: 152.063
# gaudyfea: 149.817
# worldlyventuri: 189.585
# pipeathlete: 157.340
# bashrower: 150.881
# pleasinghoop: 93.844
# quadratcranky: 118.582
# poohvireo: -50.943
# looroasting: -65.103
# ceilinjuries: 128.475
# unicyclistamiable: 152.761
# trapdoormongrel: 60.454
# heaterinert: -84.532
# gaudyfea: 60.409
# loindecorate: 60.617
# latticelaboratory: -75.717
# allocatesposts: 66.007
# troubledseptum: 59.953
# tendonwench: -75.840
# snowdonevasive: -77.530
# cranesurgeon: 60.273
# snaildossier: 86.086
# rappelarias: -35.995
# easybobolink: -35.815
# europiumcentury: 79.293
# chiselleddessicants: -54.518
# namibianstabbing: 53.284
# croutonwrack: 152.051
# grabbig: -44.284
# batchquickest: -31.909
# badgefields: -69.517
# simplicityfairy: 81.713
# cleaningburnt: 220.701
# troubledseptum: 56.530
# coatprecious: -71.146
# meggingswine: 6.750
# clucklinnet: 121.256
# batchquickest: 122.015
# bashrower: 150.424
# dronessomersault: -84.322
# easybobolink: -84.452
# colonclipper: 59.619
# unguardedgiant: 57.714
# eminentallergy: -54.967
# souffleutility: 118.152
# pipeathlete: -85.502
# gnarledbaggy: -52.197
# synonympatisserie: -53.545
# advisorlanguage: 142.111
# lasttaiga: -68.995
# apronextension: -68.995
# bracesworkable: -47.330
# turnoverlovesick: -40.266
# behaveterminal: -72.617
# amuckpoints: 43.499
# bluetailgodwottery: 89.785
# bluetailgodwottery: 87.020
# cowardlyabout: -37.924
# coatprecious: -52.005
# mtvgrosbeak: -37.869
# figsql: -74.740
# dweebspices: -40.324
# bismuthcolloquial: 163.949
# hypergalaxyfibula: 163.949
# eontop: 10.233
# namibianstabbing: 88.561
# flakyunlawful: 62.740
# bunchmeats: -44.082
# cleaningburnt: 97.145
# poundingfrustum: -42.053
# handywrist: 114.058
# flinkjordan: 113.962
# coatprecious: 110.430
# nursingrash: 111.176
# actuallyfoot: -37.956
# wonderfulscullian: 175.184
# trapdoormongrel: 125.369
# bluetailgodwottery: 65.344
# flakyunlawful: 59.801
# behaviourverbena: -78.816
# flinkjordan: -78.768
# emeraldclippers: -76.782
# trapdoormongrel: 62.248
# producecoven: 33.997
# snaildossier: -54.104
# starbucksbluetail: -53.805
# starbucksbluetail: 60.786
# cuboidpass: 95.595
# evaporatingplug: 61.519
# unguardedgiant: 153.462
# copalinstruct: -70.025
# bluetailgodwottery: 55.203
# risottospell: 50.349
# badgefields: 59.180
# snaildossier: 65.140
# submittedwavelength: 103.323
# translatecyclist: 129.639
# easybobolink: 126.834
# musicalchampagne: 130.904
# gammagot: 129.990
# crepegrape: 125.642
# parallelconcerned: 124.144
# burritoscarriage: 94.111
# dampedbrioche: 111.420
# starbucksbluetail: 111.762
# neckedjre: -52.663
# realtorcaustic: 76.850
# fundingticket: 66.000
# gnarledbaggy: 65.717
# hoursethanoate: 78.190
# specifiedinnovative: 78.216
# advisorlanguage: 78.216
# decanterbalance: 48.716
# wonderfulscullian: 49.875
# bismuthcolloquial: -85.521
# copalinstruct: 56.394
# bonelliseal: -166.600
# badgefields: 60.334
# compareas: 62.083
# canalhateful: -30.269
# wordsundress: -30.811
# risottospell: -30.775
# burntrifle: 116.450
# horsesmultiply: -53.706
# fizzlehelp: -37.088
# dronessomersault: -82.442
# evaporatingplug: -42.202
# freelysociable: -26.957
# heomicron: -55.399
# submittedwavelength: -59.986
# sectionssqueaky: -69.045
# turnoverlovesick: -64.145
# dotwazzack: -47.396
# casesslippery: 69.359
# decanterbalance: 117.935
# expecteffective: -35.735
# translatecyclist: -40.684
# axlevirtue: -40.886
# twitequiver: -52.344
# heaterinert: -52.597
# quadratcranky: -52.284
# showerspain: -52.682
# ellipticalfabricator: -6.946
# maintainwiggly: 3.262
# handywrist: 86.849
# frequencywould: 87.967
# worldlyventuri: 11.532
# maintainwiggly: 28.433
# crepegrape: 118.187
# analbar: -53.850
# ellipticalfabricator: -53.900
# fizzlehelp: -53.750
# freelysociable: -54.000
# expecteffective: -53.750
# parallelconcerned: -53.600
# binomialapathetic: -53.234
# hoursethanoate: 30.541
# stunassured: 156.216
# globeshameful: 136.485
# badgefields: 36.570
# copalinstruct: 76.477
# alloweruptions: 76.849
# gilletteclammy: -49.464
# privacyhaunt: 55.183
# croutonwrack: -36.406
# grabbig: -36.451
# organicmajor: -65.920
# ashamedmuscles: -48.779
# pipeathlete: 22.650
# ashamedmuscles: -55.936
# metaiota: 88.006
# cheapersyllable: 64.534
# actuallyfoot: -35.661
# spiritedjump: 64.021
# flinkjordan: 116.150
# casesslippery: 140.235
# emeraldclippers: 76.005
# langeredsubset: -35.072
# cowardlyabout: -35.244
# wordsundress: -35.328
# specifiedinnovative: -33.529
# instantthwack: -34.419
# realtorcaustic: -35.979
# epsiloncloning: -52.874
# globeshameful: -35.526
# hypergalaxyfibula: -34.633
# quadratcranky: -35.406
# meatsoffbeat: -39.776
# clucklinnet: -34.574
# freelysociable: -36.905
# belchedsodding: -35.753
# hoursethanoate: 7.970
# pancakesgrebe: -38.794
# opticsdiameter: -66.353
# craytugofwar: 64.155
# hypergalaxyfibula: 136.647
# singesculptor: 70.744
# unguardedgiant: -38.592
# frequencywould: -74.198
# privacyhaunt: 73.467
# apronextension: 46.210
# unbalancedprotoplanet: -50.250
# snowdonevasive: -49.168
# ashamedmuscles: -48.999
# xslhopeful: -49.222
# fattyoddball: -48.478
# turnoverlovesick: -49.793
# phobosstaccato: -49.300
# deficientclunking: 56.025
# ellipticalfabricator: -48.474
# peacefulceaseless: -47.399
# bracesworkable: 70.033
# strungebay: 70.008
# sortinterior: 79.454
# dampedbrioche: 75.113
# bunchmeats: 3.840
# unguardedgiant: 136.520
# guavaconfide: 51.480
# snowdonevasive: 52.701
# burritoscarriage: 49.802
# radicandoceanic: -72.492
# alloweruptions: 51.022
# casesslippery: 50.845
# producecoven: -85.533
# troubledseptum: -85.679
# flickcanapes: -85.537
# flinkjordan: 55.065
# tweezerscurve: 59.017
# producecoven: 55.234
# completionskylark: 51.251
# bashrower: 51.611
# epsiloncloning: 36.990
# instantthwack: -59.157
# compareas: -66.439
# impetuousfurbelows: -45.032
# privacyhaunt: -45.419
# looroasting: -46.591
# microwavejar: -47.639
# impetuousfurbelows: -85.278
# planktonuses: -79.037
# raggedshrink: -35.238
# behaveterminal: 89.200
# ledgeindeed: 85.720
# colonclipper: 105.765
# radicandoceanic: 104.321
# expecteffective: 105.084
# lasttaiga: -49.435
# tubingwheatear: -48.126
# ellipticalfabricator: -48.893
# bluetailgodwottery: 148.826
# risottospell: 56.363
# behaveterminal: 129.376
# lymphomamellow: 136.863
# hoovessquares: 78.918
# lasttaiga: 78.918
# blythpulse: 176.727
# pipeathlete: 99.665
# clucklinnet: -77.916
# somethingalbedo: 76.383
# fattyoddball: 93.434
# upbeatodd: 114.273
# hoovessquares: 137.953
# flakyunlawful: 154.840
# microwavejar: 156.321
# cowardlyabout: 156.608
# disjointtoday: 78.700
# figsql: 84.115
# amuckpoints: 79.710
# trapdoormongrel: 51.614
# figsql: 4.095
# burritoscarriage: 4.233
# clucklinnet: 4.032
# clucklinnet: 3.402
# bunchmeats: 5.188
# snaildossier: -28.695
# namibianstabbing: -27.971
# listenerabandoned: -28.371
# lasttaiga: -28.359
# eminentallergy: -28.688
# looroasting: -46.555
# babyambitious: -46.475
# fixnumquicklime: -45.757
# trapdoormongrel: 51.388
# fixnumquicklime: -39.433
# micaassistant: -38.264
# badgefields: -28.052
# bracesworkable: -37.043
# snowdonevasive: -24.396
# xslhopeful: -38.592
# loindecorate: -74.826
# pipetsrockers: -39.223
# tubingwheatear: -33.225
# ashamedmuscles: -33.052
# gaudyfea: -28.044
# alloweruptions: -97.221
# actuallyfoot: -96.142
# copalinstruct: 51.600
# cheapersyllable: 51.395
# disjointtoday: 51.388
# grabbig: 93.357
# cheapersyllable: 128.350
# hoovessquares: 149.083
# hypergalaxyfibula: 156.488
# translatecyclist: 155.633
# barnevidence: 136.474
# unicyclistamiable: 93.205
# blythpulse: 90.279
# producecoven: -44.234
# stylishmugs: 164.743
# driftmvc: 189.378
# eontop: 189.083
# burntrifle: 194.933
# burntrifle: 235.079
# planktonuses: 215.341
# pipetsrockers: 216.437
# spiritedjump: 210.913
# poohvireo: 206.233
# horsesmultiply: 194.796
# surmiseteenagers: 184.010
# planktonuses: 180.863
# barnevidence: 172.021
# clucklinnet: 63.216
# radicandoceanic: 179.868
# simplicityfairy: 185.233
# sectionssqueaky: 49.906
# ellipticalfabricator: 49.590
# ceilinjuries: 62.300
# dweebspices: 126.813
# alloweruptions: -94.098
# easybobolink: 54.666
# blythpulse: -63.803
# flinkjordan: -46.793
# turnoverlovesick: 55.247
# elatedunicorn: 54.700
# globeshameful: -76.138
# gaudyfea: 51.385
# spiritedjump: 69.242
# copalinstruct: -27.645
# singesculptor: 137.757
# clucklinnet: -87.611
# flickcanapes: -59.218
# flakyunlawful: 50.841
# fizzclimbing: 135.233
# gaudyfea: 109.680
# burntrifle: -43.236
# planktonuses: -77.486
# evaporatingplug: -75.044
# rigelpaunchy: -69.008
# badgefields: -73.349
# neckedjre: -76.183
# sociablelemma: -73.139
# unbalancedprotoplanet: -78.240
# actuallyfoot: -69.856
# fizzlehelp: -55.925
# flickcanapes: -46.931
# snowdonevasive: -52.047
# sociablelemma: -53.507
# alloweruptions: -47.921
# sociablelemma: -39.866
# earmarinated: -52.891
# bluetailgodwottery: -34.011
# looroasting: -46.916
# completionskylark: -46.916
# bunchmeats: 104.918
# batchquickest: 90.450
# cobolglaucous: 91.566
# pancakesgrebe: -54.982
# agenascientists: 109.408
# somethingalbedo: 109.057
# heomicron: -53.368
# organicmajor: -65.540
# latticelaboratory: -62.395
# sortinterior: -62.906
# easybobolink: -35.819
# producecoven: -44.610
# badgefields: -45.154
# ashamedmuscles: -45.739
# bonelliseal: -51.580
# pancakesgrebe: -55.499
# bonelliseal: -71.565
# specifiedinnovative: -84.618
# driftmvc: -84.478
# burntrifle: -84.681
# analbar: -84.756
# craytugofwar: -84.652
# smackswallow: -84.786
# cartridgesbummage: -40.179
# cartridgesbummage: 118.781
# heaterinert: -48.177
# spiritedjump: -56.392
# rigelpaunchy: 76.954
# musicalchampagne: -50.252
# sociablelemma: -33.234
# behaviourverbena: -34.857
# wisefumbling: -33.809
# unguardedgiant: -33.092
# guavaconfide: -32.119
# impetuousfurbelows: -32.331
# expecteffective: 47.054
# dotwazzack: 43.007
# translatecyclist: -35.761
# ledgeindeed: -34.638
# replacedbevy: -35.022
# planktonuses: -35.924
# meatsoffbeat: -33.658
# opticsdiameter: -33.544
# globeshameful: -36.616
# ellipticalfabricator: -32.231
# stunassured: -54.028
# fizzlehelp: -46.617
# langeredsubset: -46.091
# chiselleddessicants: -49.704
# colonclipper: -46.472
# decanterbalance: -45.035
# strungebay: -51.382
# bunchmeats: -155.333
# twitequiver: 28.737
# gruntdrive: -46.464
# sortinterior: -46.523
# cartridgesbummage: -46.468
# fattyoddball: -46.431
# figsql: -45.023
# axlevirtue: -45.018
# turnoverlovesick: -33.641
# rappelarias: 7.962
# instantthwack: 31.417
# meatsoffbeat: 33.099
# behaveterminal: 33.575
# pleasinghoop: 36.716
# raggedshrink: -78.785
# souffleutility: 92.584
# strungebay: 90.258
# alloweruptions: -73.635
# moderatohorn: 72.594
# carrionscream: 35.851
# pipetsrockers: 36.790
# realtorcaustic: 40.330
# blythpulse: 43.361
# realtorcaustic: 43.557
# privacyhaunt: 43.520
# emeraldclippers: 45.234
# fixnumquicklime: -34.260
# sectionssqueaky: -33.950
# earmarinated: -34.535
# lickerbond: -34.991
# fixnumquicklime: -32.743
# badgefields: -32.210
# nursingrash: -84.457
# pancakesgrebe: -84.583
# nursingrash: -87.021
# ellipticalfabricator: -74.170
# amuckpoints: -74.478
# craytugofwar: -33.677
# applyingbaker: -74.741
# geologybeeping: -87.907
# snaildossier: -85.241
# hoovessquares: 34.118
# eminentallergy: 34.165
# eontop: 34.337
# heaterinert: 34.454
# rubbishbladder: 34.511
# actuallyfoot: 34.689
# rappelarias: 34.580
# musicalchampagne: 34.137
# pleasinghoop: 51.419
# chichazard: 51.481
# strungebay: -74.887
# phobosstaccato: 116.476
# sectionssqueaky: 117.221
# axlevirtue: 114.132
# unicyclistamiable: 114.793
# sortinterior: 114.774
# risottospell: 146.564
# troubledseptum: 105.805
# troubledseptum: -84.342
# organicmajor: 30.701
# cobolglaucous: -74.650
# troubledseptum: -74.400
# snaildossier: -74.917
# unbalancedprotoplanet: -76.453
# badgefields: -75.950
# backedammeter: -74.388
# clucklinnet: -84.444

# %% [markdown]
# Here, each variable is a _column_ (not a row, like in the previous example!), then we can use **zip** to create the
# dataframe.

# %%
users_in_dataframe = pd.DataFrame( list(zip(line_user,line_var1,line_var2)) )
users_in_dataframe.head(10)
# Out:
#                    0           1            2
# 0  parallelconcerned  145.391881  -6.081689\n
# 1           driftmvc    145.7887  -5.207083\n
# 2     snowdonevasive  144.295861  -5.826789\n
# 3      cobolglaucous  146.726242  -6.569828\n
# 4        stylishmugs   147.22005  -9.443383\n
# 5  hypergalaxyfibula  143.669186  -3.583828\n
# 6      pipetsrockers  -45.425978  61.160517\n
# 7     bracesworkable  -51.678064  64.190922\n
# 8       spiritedjump  -50.689325  67.016969\n
# 9       barnevidence  -68.703161  76.531203\n

# %% [markdown]
# ***
#
# We'll see more functions during the semester and you can always search for them and information on them online (remember, google is your best friend) !!

# %% [markdown]
# %matplotlib inline
# plt.pyplot.plot(users_in_dataframe[1], users_in_dataframe[2], ".", markersize=1.1)

# %% [markdown]
# We can also get basic statistics on the data frame.  You'll figure out more about this in your homework:

# %%
users_in_dataframe.describe()
# Out:
#                 0          1     2
# count        8103       8103  8103
# unique        200       7983  7982
# top     compareas  34.584025   1\n
# freq           59          4     4

# %% [markdown]
# #### Extra added bonus!!   ---  Auto-complete

# %% [markdown]
# One of the most useful things about IPython notebook is its tab completion.
#
# Try this: put your cursor just after `sqrt(` in the cell below and press `Shift + Tab` 4 times, slowly

# %%
np.sqrt(
# Out:
#   File "<ipython-input-33-f88ced56917d>", line 1
#     np.sqrt(
#             ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# I find this amazingly useful. I think of this as "the more confused I am, the more times I should press Shift+Tab". Nothing bad will happen if you tab complete 12 times.
#
# Okay, let's try tab completion for function names! Just hit `Tab` when typing below to get suggestions.

# %%
np.sq

# %% [markdown]
# This is super useful when (like me) you forget the names of everything!

# %% [markdown]
# ## Hands-on

# %% [markdown]
# To master your new-found knowledge of Python, try these hands-on examples.
#
# Your homeworks will be in a similar format to this section.

# %% [markdown]
# **1\. Create one list of 5 fruits and another one with 5 colors**

# %% [markdown]
# **2\. Go through each fruit (first list) and print out the name of the fruit with one color of the second list **
#
# (don't worry, it doesn't have to be the color of the fruit!)
#
# Example of what you should print:  _apple is purple_

# %% [markdown]
# **3\. Add two new fruits to your list with a _BUILT-IN_ function **
#
# ( Look for the function with the **TAB** hint! )

# %% [markdown]
# **4\. Use the list of fruits and sort the names (put them in alphabetical order) **
#
# ( Hint: Numpy has a great function for that!)

# %% [markdown]
# **5\. Create a new empty list called "count_letters". Go through your list of fruits, and for each one, add an entry to that new list (count_letters) telling the number of letters each fruit name.**
#
# Example of what you should print: _apple is 5 letters_

# %% [markdown]
# ** 6\. Make a function called `one_more_change` that takes a list (input_list) and returns a new list (output_list) where each element of the original will be increased by 1 and divided by 2. **

# %%
def one_more(input_list):
    output_list = []   # What should we do?
    
    return output_list

# %% [markdown]
# ** 7\. Use the previous function to change the value of a list of 10 random numbers. **
